# %% [markdown]
# # 1. (Total points: 30)
# Consider the grid-world domain shown below. The possible actions are the four
# cardinal direction movements: up, down, left and right. All state transitions are deterministic.
# Moving in some direction changes the agent’s position by one square in the given direction, unless it
# bumps into a wall or hits the edge of the world, in which case the position stays unchanged. Falling
# in the hole or reaching the goal both leads to terminal states. The agent gets a reward of +10 points
# for reaching the goal state, -1 for bumping into a wall or the edge of the world, and -50 for falling
# into a hole. Future rewards are discounted at a rate of 0.9 per step.

# %% [markdown]
# ## (a) (5 points)
# What is the value of state a under the optimal policy?
# ***

# %% [markdown]
# We use the formula:
#
# $
# V(s) = R(s) + \gamma \times V(s')
# $

# %%
reward_goal = 10
reward_non_terminal = 0
discount_factor = 0.9

value_goal = reward_goal  
value_f = reward_non_terminal + discount_factor * value_goal
value_e = reward_non_terminal + discount_factor * value_f 
value_d = reward_non_terminal + discount_factor * value_e 
value_c = reward_non_terminal + discount_factor * value_d 
value_b = reward_non_terminal + discount_factor * value_c 
value_a = reward_non_terminal + discount_factor * value_b  

print(f"Value of state a under the optimal policy is: {value_a}")
# Out:
# Value of state a under the optimal policy is: 5.3144100000000005

# %% [markdown]
# ## (b) (5 points)
# Q-Learning is an Off-Policy TD control method while Sarsa is said to be On-Policy. What does that mean?
# ***

# %% [markdown]
# Firstly, one is an **Off-policy** method while the other is an **On-policy** method.
#
# **Off-policy** methods try to fit a target policy from data that is generated from another, behaviour policy
#
# **On-policy** methods update the existing policy, so the policy used for learning is the same one that is used for behaviour. Meaning the agent will learn from the policy it is actually following.
#
# **SARSA** is more cautious while **Q-learning** aims for the higher reward, even when it is risky. As we saw in the cliff walking example, SARSA chose the safe path while Q-learning aimed for the more risky path.
#
# $$ SARSA $$
# $$
# Q(s, a) \leftarrow Q(s, a) + \alpha \left[ r + \gamma Q(s', a') - Q(s, a) \right]
# $$\
# SARSA uses the action a' taken in s' for the Q-value update, making it take the penalty from falling in the hole more into account.
#
# $$ Q-Learning $$
# $$ Q(s, a) \leftarrow Q(s, a) + \alpha \left[ r + \gamma \max_{a'} Q(s', a') - Q(s, a) \right] $$
# Here we can see that the Q-value update is done using the maximum estimated future reward, even when the agent didnt take the action. This makes the algorithm optimistic as it assumes the future behaviour is greedy and risky.
#
# They major differences in the methods therefore lie in how they update their estimates and exploration vs exploitation where **SARSA** is more balanced while **Q-Learning** is inclined towards exploiting for higher rewards.

# %% [markdown]
# ## (c) (10 points)
# Suppose Sarsa and Q-Learning would be used to learn a policy for the problem
# (without fixing the episodes, but picking them using an epsilon-greedy policy). Which policies
# (preferred paths) would you expect the two algorithms to learn? Justify your answer.
# ***

# %% [markdown]
# It is likely that Q-learning will learn the optimal path (a-b-c-d-e-f), even though it is riskier, while SARSA will go around to avoid the hole, as it is much safer (a-g-h-i-j-k-l-m-n-f).
#
# Like we explain in the answer above, SARSA will recognise and take into account that following the optimal path will also make falling into the hole increasinly likely.

# %% [markdown]
# ## (d) (10 points)
# Does the value for ϵ matter for the answer of the previous question? How? (That
# is, which of the methods is affected in which way by changing ϵ?)
# ***

# %% [markdown]
# **SARSA**
# High ϵ, or more exploration means that it is more likely that we explore risky acitons and end up in the hole, since SARSA is an on-policy method, it will learn to avoid the hole in the end though. If we lower the ϵ too much the agent will behave safely but might learn not so good paths, therefore never discovering the optimal path.
#
# **Q-Learning**
# High ϵ, now the agent will explore more, taking inccreased risks, but as an off-policy method it should find the optimal policy eventually, it could take a lot of time to converge though. If we lower ϵ too much, we end up in a similar case as with SARSA, the agent might stick to suboptimal paths, never learning the best paths.
#
# One option would be to  gradually reducing ε in which case both methods will asymptotically converge to the optimal policy
#
# So the value of ϵ will affect both algorithms.

# %% [markdown]
# # 2. Deadly Triad (Total points: 20)

# %% [markdown]
# ## (a) (5 points)
# Shortly explain what is meant by ”deadly triad” when discussing reinforcement learning algorithms. (What is the problem and what causes it?)
# ***

# %% [markdown]
# The deadly triad is when all three of **Function Approximation**, **Bootsrapping** and **Off-Policy Training** are mixed together, making algorithms unstable and potentially diverge. But this is not the case when the methods are carefully balanced, using only 1 or 2 elements together, the dangers of the deadly triad can be avoided. So the problem is when we mix them all together, they become unstable and can diverge.
#
# **Function Approximation** is probably the most important element, since without it it's impossible to scale to large problems, but as in the name, are approximations.. leading to potential errors that will get propogated into our future estimates
#
# **Bootstrapping** comes in handy as its useful for data- and computational efficiency, but similar to the function approximation, we are using estimates to estimate future values, so if the estimates are off, they will spiral. Bootstrapping can also introduce higher variance into our value function updates.
#
# **Off-Policy Training** can be optional but can also be essential for advanced use cases if we are learning policies in parallel but often on-policy methods can be adequate and for instance in model-free RL we could choose SARSA instead of Q-learning.

# %% [markdown]
# ## (b) (15 points)
# Baird’s counterexample is used to illustrate a potential instability of reinforcement
# learning algorithms. Show that dropping any of the three parts of the deadly triad (function
# approximation, temporal difference learning/bootstrapping, off-policy learning) would result in
# convergence to the correct values for Baird’s counterexample.
# ***

# %% [markdown]
# If we remove **Function Approximation** then we go to a tabular setting with a finite number of states and actions. In this case each state action pair will have its own unique value.
#
# Removing **Bootstrapping** we are no longar working with estimates, which removes noise caused by potential inaccurasies, and therefore get a guarantee to converge from the law of large numbers.
#
# Dropping **Off-Policy Learning** we wont have a distribution mismatch since we wont have two policies, and the same policy is generating and updating the estimates. This will result in more stable learning and we will converge.

# %% [markdown]
# # 3. (Total points: 100)
# Consider the Lunar Lander environment from https://gymnasium.farama.org/.\
# The goal is to land a spacecraft on the moon safely (without crashing) and with as little manouvering
# as possible. The state space is 8-dimensional and consists of
# - horizontal and vertical position of the lander (x and y)
# - velocities in x and y direction
# - the angle of the lander and angular velocity
# - for both legs whether they touch the ground or not
#
#
# Your task is to use Reinforcement Learning to find a good policy for this setting.

# %% [markdown]
# ## (a) (10 points)
# Implement a purely random agent for the enviroment as a baseline to compare other
# agents to.

# %%
import gymnasium as gym

env = gym.make("LunarLander-v2")

num_episodes = 100

episode_rewards = []

for episode in range(num_episodes):
 
    observation, info = env.reset()
    total_reward = 0
    done = False
    
    while not done:
        # random action
        action = env.action_space.sample()
        
        observation, reward, terminated, truncated, info = env.step(action)
        
        # update rewards
        total_reward += reward
        
        done = terminated or truncated

    episode_rewards.append(total_reward)

env.close()

random_avg_reward = sum(episode_rewards) / num_episodes
print(f"Average Reward: {random_avg_reward}")
# Out:
# Average Reward: -176.53557122444087

# %% [markdown]
# ## (b) (10 points)
# In order to use a tabular approach for solving the problem, you need to first discretize the state space. One way to achieve that is to split each attribute (except for the boolean
# ones) evenly into n intervals each, resulting in at most 4 ∗ n
# 6 different states to consider (not
# all of those might be reachable). Implement a function that maps each state/observation to its
# discretized version. Keep n as a parameter to tune later and set n = 10 as a default.

# %%
def discretize_state(state, n=10):
    number_of_buckets = (n, n, n, n, n, n, 2, 2)  # buckets in each dimension
    state_value_bounds = list(zip(env.observation_space.low, env.observation_space.high))

    state_value_bounds[0] = [-1, 1]  # Position x
    state_value_bounds[1] = [-1, 1]  # Position y
    state_value_bounds[2] = [-1, 1]  # vel x
    state_value_bounds[3] = [-1, 1]  # vel y
    state_value_bounds[4] = [-1, 1]  # angle
    state_value_bounds[5] = [-1, 1]  # angular vel
    state_value_bounds[6] = [0, 1]   # leg1
    state_value_bounds[7] = [0, 1]   # leg2

    bucket_indexes = []
    for i in range(len(state)):
        if state[i] <= state_value_bounds[i][0]:
            bucket_index = 0
        elif state[i] >= state_value_bounds[i][1]:
            bucket_index = number_of_buckets[i] - 1
        else:
            bound_width = state_value_bounds[i][1] - state_value_bounds[i][0]
            offset = (number_of_buckets[i] - 1) * state_value_bounds[i][0] / bound_width
            scaling = (number_of_buckets[i] - 1) / bound_width
            bucket_index = int(round(scaling * state[i] - offset))
        bucket_indexes.append(bucket_index)
    return tuple(bucket_indexes)

# Test the updated function
# Reset the environment to get an initial state
initial_state, _ = env.reset()

# Discretize the initial state using the new function
discrete_initial_state = discretize_state(initial_state)

print(f"Initial state: {initial_state}")
print(f"Discrete initial state: {discrete_initial_state}")
# Out:
# Initial state: [-0.00248137  1.4007292  -0.25134996 -0.4529305   0.00288207  0.05693451
#   0.          0.        ]
# Discrete initial state: (2, 4, 1, 1, 2, 2, 0, 0)

# %% [markdown]
# ## (c) (15 points)
# Implement on-policy Monte Carlo control to learn a policy for the task. Use a
# tabular approach for storing Q(s, a)
# Use an ϵ-greedy policy with ϵ = 0.1, a learning rate of 0.1 and discount future rewards with
# 0.99.

# %%
import numpy as np
from collections import defaultdict

env = gym.make("LunarLander-v2")
n_episodes = 5000
epsilon = 0.1
alpha = 0.1
gamma = 0.99

Q = defaultdict(lambda: np.zeros(env.action_space.n))
G = defaultdict(lambda: np.zeros(env.action_space.n))
N = defaultdict(lambda: np.zeros(env.action_space.n))

def choose_action(state):
    if np.random.rand() < epsilon:
        return np.random.choice(env.action_space.n)
    else:
        return np.argmax(Q[state])

for episode in range(1, n_episodes + 1):
    episode_rewards = 0
    state, _ = env.reset()
    state = discretize_state(state)
    
    done = False
    episode_states_actions = []
    episode_rewards = []
    
    # simulate an episode using current policy
    while not done:
        action = choose_action(state)
        # action = np.argmax(Q[state])
        next_state, reward, terminated, truncated, _ = env.step(action)
        next_state = discretize_state(next_state)
        
        episode_states_actions.append((state, action))
        episode_rewards.append(reward)
        
        state = next_state
        done = terminated or truncated
    
    total_reward = 0
    for t in reversed(range(len(episode_states_actions))):
        state, action = episode_states_actions[t]
        reward = episode_rewards[t]
        total_reward += reward
        # accumulate the returns for the state, action pair in the current timestep
        G[state][action] += (gamma ** t) * reward 
        # count the number of visits to each state, action pair 
        N[state][action] += 1
        # update Q based on the average of returns for the state, action pair
        Q[state][action] += (G[state][action] - Q[state][action]) / N[state][action]

    if episode % 100 == 0:
        print(f"Episode {episode} completed. Total reward: {total_reward}")

# %%
n_test_episodes = 100
total_rewards = 0.0

for episode in range(n_test_episodes):
    state, _ = env.reset()
    state = discretize_state(state)
    done = False
    episode_reward = 0.0
    
    while not done:
        action = np.argmax(Q[state])  # action with the highest Q-value
        next_state, reward, terminated, truncated, _ = env.step(action)
        next_state = discretize_state(next_state)
        
        episode_reward += reward
        state = next_state
        done = terminated or truncated
    
    total_rewards += episode_reward

average_reward = total_rewards / n_test_episodes
print(f"Average reward over {n_test_episodes} test episodes: {average_reward}")
# Out:
# Average reward over 100 test episodes: -151.03476423478537

# %% [markdown]
# ## (d) (10 points)
# Train a policy using MC and evaluate it. Plot a curve showing the progress of
# training, for example, the quality of the policy (average return) over the number of training
# episodes. Compare the performance to a purely random agent. What can be said about the
# performance of the algorithm with these parameters and this state representation on the given
# task?

# %%
import math
def decay_function(episode):
    min_epsilon = 0.01
    max_epsilon = 1.0
    return max(min_epsilon, min(max_epsilon, 1.0 - math.log10((episode + 1) / (n_episodes * 0.1))))

def evaluate_greedy_policy(env, Q, n_episodes=100):
    total_rewards = 0
    for _ in range(n_episodes):
        state, _ = env.reset()
        state = discretize_state(state)
        done = False
        episode_rewards = 0
        
        while not done:
            action = np.argmax(Q[state])
            
            next_state, reward, terminated, truncated, _ = env.step(action)
            next_state = discretize_state(next_state)
            
            episode_rewards += reward
            state = next_state
            done = terminated or truncated
            
        total_rewards += episode_rewards
        
    average_reward = total_rewards / n_episodes
    return average_reward

# %%
env = gym.make("LunarLander-v2")

n_episodes = 10000
alpha = 0.1
gamma = 0.999
step_size = 200  
moving_average_window = 100  

Q = defaultdict(lambda: np.zeros(env.action_space.n))
N = defaultdict(lambda: np.zeros(env.action_space.n))

def choose_action(state, epsilon):
    if np.random.rand() < epsilon:
        return np.random.choice(env.action_space.n)
    else:
        return np.argmax(Q[state])

curr_epsilon = 1.0

def decay_function(episode):
    min_epsilon = 0.01
    max_epsilon = 1.0
    return max(min_epsilon, min(max_epsilon, 1.0 - math.log10((episode + 1) / (n_episodes * 0.1))))

episode_numbers = []
moving_average_rewards = []
greedy_rewards = []
greedy_episodes = []
last_n_rewards = []

for episode in range(1, n_episodes + 1):
    if episode % 500 == 0: 
        avg_reward = evaluate_greedy_policy(env, Q)
        print(f"Episode {episode}, Average reward over 100 episodes with greedy policy: {avg_reward}")
    
        # store greedy result
        greedy_rewards.append(avg_reward)
        greedy_episodes.append(episode)
    curr_epsilon = decay_function(episode)
    
    state, _ = env.reset()
    state = discretize_state(state)
    
    done = False
    episode_states_actions = []
    episode_rewards = []
    
    while not done:
        action = choose_action(state, curr_epsilon)
        next_state, reward, terminated, truncated, _ = env.step(action)
        next_state = discretize_state(next_state)
        
        episode_states_actions.append((state, action))
        episode_rewards.append(reward)
        
        state = next_state

        done = terminated or truncated

    G = 0
    for t in reversed(range(len(episode_states_actions))):
        state, action = episode_states_actions[t]
        reward = episode_rewards[t]
        
        G = gamma * G + reward
        N[state][action] += 1
        
        Q[state][action] += (G - Q[state][action]) / N[state][action]
    
    total_episode_reward = sum(episode_rewards)
    last_n_rewards.append(total_episode_reward)
    
    if len(last_n_rewards) > moving_average_window:
        last_n_rewards.pop(0)
    
    moving_average = np.mean(last_n_rewards)
    
    if episode % (step_size * 4) == 0:
        episode_numbers.append(episode)
        moving_average_rewards.append(moving_average)
        print(f"Episode {episode} completed. Moving Average Reward over last {moving_average_window} episodes: {moving_average}")
# Out:
# Episode 200 completed. Moving Average Reward over last 100 episodes: -180.91632128478835
# Episode 400 completed. Moving Average Reward over last 100 episodes: -170.56159332662915
# Episode 500, Average reward over 100 episodes with greedy policy: -157.2653038341322
# Episode 600 completed. Moving Average Reward over last 100 episodes: -187.4010096110816
# Episode 800 completed. Moving Average Reward over last 100 episodes: -180.5915249956649
# Episode 1000, Average reward over 100 episodes with greedy policy: -156.3178826476542
# Episode 1000 completed. Moving Average Reward over last 100 episodes: -175.43919771765002
# Episode 1200 completed. Moving Average Reward over last 100 episodes: -147.4477267173074
# Episode 1400 completed. Moving Average Reward over last 100 episodes: -127.06079990294742
# Episode 1500, Average reward over 100 episodes with greedy policy: -74.31566853058526
# Episode 1600 completed. Moving Average Reward over last 100 episodes: -124.08327562575055
# Episode 1800 completed. Moving Average Reward over last 100 episodes: -106.02535342785957
# Episode 2000, Average reward over 100 episodes with greedy policy: -60.535563483585285
# Episode 2000 completed. Moving Average Reward over last 100 episodes: -94.90723638810096
# Episode 2200 completed. Moving Average Reward over last 100 episodes: -85.06485556874114
# Episode 2400 completed. Moving Average Reward over last 100 episodes: -82.97847145461122
# Episode 2500, Average reward over 100 episodes with greedy policy: -28.506684435675503
# Episode 2600 completed. Moving Average Reward over last 100 episodes: -80.99348493873028
# Episode 2800 completed. Moving Average Reward over last 100 episodes: -76.60473578604453
# Episode 3000, Average reward over 100 episodes with greedy policy: -23.53980598120138
# Episode 3000 completed. Moving Average Reward over last 100 episodes: -68.73693100601346
# Episode 3200 completed. Moving Average Reward over last 100 episodes: -59.46106184595995
# Episode 3400 completed. Moving Average Reward over last 100 episodes: -60.36402490105618
# Episode 3500, Average reward over 100 episodes with greedy policy: -12.164437158353607
# Episode 3600 completed. Moving Average Reward over last 100 episodes: -54.83568736257716
# Episode 3800 completed. Moving Average Reward over last 100 episodes: -43.32665396981233
# Episode 4000, Average reward over 100 episodes with greedy policy: -13.410695679147189
# Episode 4000 completed. Moving Average Reward over last 100 episodes: -53.97267607849945
# Episode 4200 completed. Moving Average Reward over last 100 episodes: -47.462345593953636
# Episode 4400 completed. Moving Average Reward over last 100 episodes: -43.19810358017553
# Episode 4500, Average reward over 100 episodes with greedy policy: -17.94240129611673
# Episode 4600 completed. Moving Average Reward over last 100 episodes: -43.69470753996406
# Episode 4800 completed. Moving Average Reward over last 100 episodes: -43.52417033466949
# Episode 5000, Average reward over 100 episodes with greedy policy: -7.072707897318895
# Episode 5000 completed. Moving Average Reward over last 100 episodes: -39.804325393387295
# Episode 5200 completed. Moving Average Reward over last 100 episodes: -30.634612938875517
# Episode 5400 completed. Moving Average Reward over last 100 episodes: -30.04014218373663
# Episode 5500, Average reward over 100 episodes with greedy policy: 2.696954063807384
# Episode 5600 completed. Moving Average Reward over last 100 episodes: -26.135248806435783
# Episode 5800 completed. Moving Average Reward over last 100 episodes: -29.9910732519501
# Episode 6000, Average reward over 100 episodes with greedy policy: 2.184575881517795
# Episode 6000 completed. Moving Average Reward over last 100 episodes: -29.505185217754537
# Episode 6200 completed. Moving Average Reward over last 100 episodes: -22.972404835921463
# Episode 6400 completed. Moving Average Reward over last 100 episodes: -16.563869913290187
# Episode 6500, Average reward over 100 episodes with greedy policy: -9.08050588925335
# Episode 6600 completed. Moving Average Reward over last 100 episodes: -23.710502291573867
# Episode 6800 completed. Moving Average Reward over last 100 episodes: -27.15760669412361
# Episode 7000, Average reward over 100 episodes with greedy policy: 8.260442210077573
# Episode 7000 completed. Moving Average Reward over last 100 episodes: -20.253297463140747
# Episode 7200 completed. Moving Average Reward over last 100 episodes: -19.237441883318514
# Episode 7400 completed. Moving Average Reward over last 100 episodes: -11.634013769441571
# Episode 7500, Average reward over 100 episodes with greedy policy: 3.597413310669813
# Episode 7600 completed. Moving Average Reward over last 100 episodes: -14.791843539566239
# Episode 7800 completed. Moving Average Reward over last 100 episodes: -9.234866141215344
# Episode 8000, Average reward over 100 episodes with greedy policy: 9.575781061778155
# Episode 8000 completed. Moving Average Reward over last 100 episodes: -12.794440820553291
# Episode 8200 completed. Moving Average Reward over last 100 episodes: -6.306695974433837
# Episode 8400 completed. Moving Average Reward over last 100 episodes: -6.915095643927029
# Episode 8500, Average reward over 100 episodes with greedy policy: 3.4990603684719392
# Episode 8600 completed. Moving Average Reward over last 100 episodes: 0.5499722263226228
# Episode 8800 completed. Moving Average Reward over last 100 episodes: 5.838135613149177
# Episode 9000, Average reward over 100 episodes with greedy policy: 3.9739660540624624
# Episode 9000 completed. Moving Average Reward over last 100 episodes: 21.82492915977125
# Episode 9200 completed. Moving Average Reward over last 100 episodes: 8.596515877088947
# Episode 9400 completed. Moving Average Reward over last 100 episodes: 10.656387925620624
# Episode 9500, Average reward over 100 episodes with greedy policy: 2.1637740728180637
# Episode 9600 completed. Moving Average Reward over last 100 episodes: 12.740418419076638
# Episode 9800 completed. Moving Average Reward over last 100 episodes: 14.075362171579114
# Episode 10000, Average reward over 100 episodes with greedy policy: 5.329400558351494
# Episode 10000 completed. Moving Average Reward over last 100 episodes: -4.793382372433533

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))

plt.plot(episode_numbers, moving_average_rewards, label='MC Agent (Training)', marker='o')
plt.plot(greedy_episodes, greedy_rewards, label='MC Agent (Greedy)', marker='x')
plt.axhline(y=random_avg_reward, color='r', linestyle='--', label='Random Agent')

plt.xlabel('Episodes')
plt.ylabel('Average Reward')
plt.title('Performance Comparison: MC Agent (Training vs Greedy)')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## (e) (15 points)
# Implement Q-Learning to learn a policy for the task. Use the same parameters as
# for Monte-Carlo as defaults.

# %%
env = gym.make("LunarLander-v2")

n_episodes = 10000
timesteps=1000
epsilon = 0.1
alpha = 0.1
gamma = 0.99
step_size = 200  
moving_average_window = 100  

Q = defaultdict(lambda: np.zeros(env.action_space.n))

def choose_action(state):
    if np.random.rand() < epsilon:
        return np.random.choice(env.action_space.n)
    else:
        return np.argmax(Q[state])

episode_numbers = []
moving_average_rewards = []

last_n_rewards = []  # To keep the rewards of the last MA episodes

for episode in range(1, n_episodes + 1):
    episode_rewards = 0
    state, _ = env.reset()
    state = discretize_state(state)
    
    done = False
    episode_states_actions = []
    episode_rewards = []
    
    for _ in range(timesteps):
        action = choose_action(state)
        next_state, reward, terminated, truncated, _ = env.step(action)
        next_state = discretize_state(next_state)
        
        # Update Q-table for Q(s,a)
        Q[state][action] = Q[state][action]  + alpha * (reward + gamma * np.argmax(Q[next_state]) - Q[state][action])

        episode_states_actions.append((state, action))
        episode_rewards.append(reward)
        
        state = next_state
        done = terminated or truncated

        if done:
            break

    total_episode_reward = sum(episode_rewards)
    last_n_rewards.append(total_episode_reward)
    
    if len(last_n_rewards) > moving_average_window:
        last_n_rewards.pop(0)
    
    moving_average = np.mean(last_n_rewards)
    
    if episode % step_size == 0:
        episode_numbers.append(episode)
        moving_average_rewards.append(moving_average)
        print(f"Episode {episode} completed. Moving Average Reward over last {moving_average_window} episodes: {moving_average}")
# Out:
# Episode 50 completed. Moving Average Reward over last 100 episodes: -214.35239156097677
# Episode 100 completed. Moving Average Reward over last 100 episodes: -192.28249331524472
# Episode 150 completed. Moving Average Reward over last 100 episodes: -177.55524893590592
# Episode 200 completed. Moving Average Reward over last 100 episodes: -162.2643397488201
# Episode 250 completed. Moving Average Reward over last 100 episodes: -130.2592739256253
# Episode 300 completed. Moving Average Reward over last 100 episodes: -137.5053692290203
# Episode 350 completed. Moving Average Reward over last 100 episodes: -156.54966470269474
# Episode 400 completed. Moving Average Reward over last 100 episodes: -146.2871952709784
# Episode 450 completed. Moving Average Reward over last 100 episodes: -117.2248862114919
# Episode 500 completed. Moving Average Reward over last 100 episodes: -114.4336316795566
# Episode 550 completed. Moving Average Reward over last 100 episodes: -117.2797275657249
# Episode 600 completed. Moving Average Reward over last 100 episodes: -117.0472595882365
# Episode 650 completed. Moving Average Reward over last 100 episodes: -109.82173330363226
# Episode 700 completed. Moving Average Reward over last 100 episodes: -115.95236508163616
# Episode 750 completed. Moving Average Reward over last 100 episodes: -136.95490959975098
# Episode 800 completed. Moving Average Reward over last 100 episodes: -123.8877385931149
# Episode 850 completed. Moving Average Reward over last 100 episodes: -122.0994253753854
# Episode 900 completed. Moving Average Reward over last 100 episodes: -137.64588538118377
# Episode 950 completed. Moving Average Reward over last 100 episodes: -129.98582487762846
# Episode 1000 completed. Moving Average Reward over last 100 episodes: -108.44542141952296
# Episode 1050 completed. Moving Average Reward over last 100 episodes: -115.3126760389126
# Episode 1100 completed. Moving Average Reward over last 100 episodes: -121.70327844270145
# Episode 1150 completed. Moving Average Reward over last 100 episodes: -128.23293908626707
# Episode 1200 completed. Moving Average Reward over last 100 episodes: -138.7185909511617
# Episode 1250 completed. Moving Average Reward over last 100 episodes: -119.42050414229341
# Episode 1300 completed. Moving Average Reward over last 100 episodes: -119.1872004974963
# Episode 1350 completed. Moving Average Reward over last 100 episodes: -134.20021456816278
# Episode 1400 completed. Moving Average Reward over last 100 episodes: -129.1668163684634
# Episode 1450 completed. Moving Average Reward over last 100 episodes: -127.69146032954478
# Episode 1500 completed. Moving Average Reward over last 100 episodes: -138.366127217256
# Episode 1550 completed. Moving Average Reward over last 100 episodes: -131.090744408421
# Episode 1600 completed. Moving Average Reward over last 100 episodes: -124.22681060267682
# Episode 1650 completed. Moving Average Reward over last 100 episodes: -113.23585120592892
# Episode 1700 completed. Moving Average Reward over last 100 episodes: -97.97472717422045
# Episode 1750 completed. Moving Average Reward over last 100 episodes: -110.07660662623584
# Episode 1800 completed. Moving Average Reward over last 100 episodes: -122.08644834798834
# Episode 1850 completed. Moving Average Reward over last 100 episodes: -127.98285974522177
# Episode 1900 completed. Moving Average Reward over last 100 episodes: -125.17025097501353
# Episode 1950 completed. Moving Average Reward over last 100 episodes: -121.54507897202151
# Episode 2000 completed. Moving Average Reward over last 100 episodes: -119.9084511128083
# Episode 2050 completed. Moving Average Reward over last 100 episodes: -116.86874542293775
# Episode 2100 completed. Moving Average Reward over last 100 episodes: -123.25565046519085
# Episode 2150 completed. Moving Average Reward over last 100 episodes: -120.31778790362279
# Episode 2200 completed. Moving Average Reward over last 100 episodes: -110.42491487894573
# Episode 2250 completed. Moving Average Reward over last 100 episodes: -120.10996403704412
# Episode 2300 completed. Moving Average Reward over last 100 episodes: -118.64846228428699
# Episode 2350 completed. Moving Average Reward over last 100 episodes: -117.06127638056815
# Episode 2400 completed. Moving Average Reward over last 100 episodes: -118.79931953043335
# Episode 2450 completed. Moving Average Reward over last 100 episodes: -103.07187728519389
# Episode 2500 completed. Moving Average Reward over last 100 episodes: -90.15550886836057
# Episode 2550 completed. Moving Average Reward over last 100 episodes: -98.44927155128008
# Episode 2600 completed. Moving Average Reward over last 100 episodes: -109.88467962916995
# Episode 2650 completed. Moving Average Reward over last 100 episodes: -113.25937862761567
# Episode 2700 completed. Moving Average Reward over last 100 episodes: -105.83018619664071
# Episode 2750 completed. Moving Average Reward over last 100 episodes: -102.55440247552977
# Episode 2800 completed. Moving Average Reward over last 100 episodes: -118.93319274599487
# Episode 2850 completed. Moving Average Reward over last 100 episodes: -111.91061857081661
# Episode 2900 completed. Moving Average Reward over last 100 episodes: -94.44158458603145
# Episode 2950 completed. Moving Average Reward over last 100 episodes: -89.2623686973788
# Episode 3000 completed. Moving Average Reward over last 100 episodes: -96.8212317650972
# Episode 3050 completed. Moving Average Reward over last 100 episodes: -103.51799163433303
# Episode 3100 completed. Moving Average Reward over last 100 episodes: -105.52062258321821
# Episode 3150 completed. Moving Average Reward over last 100 episodes: -104.60853766187518
# Episode 3200 completed. Moving Average Reward over last 100 episodes: -111.55152692103624
# Episode 3250 completed. Moving Average Reward over last 100 episodes: -118.70343658941027
# Episode 3300 completed. Moving Average Reward over last 100 episodes: -111.73393018249018
# Episode 3350 completed. Moving Average Reward over last 100 episodes: -89.66310834996071
# Episode 3400 completed. Moving Average Reward over last 100 episodes: -76.65483434038474
# Episode 3450 completed. Moving Average Reward over last 100 episodes: -96.14408499641404
# Episode 3500 completed. Moving Average Reward over last 100 episodes: -96.19780897145027
# Episode 3550 completed. Moving Average Reward over last 100 episodes: -104.79786445334899
# Episode 3600 completed. Moving Average Reward over last 100 episodes: -112.1067895125727
# Episode 3650 completed. Moving Average Reward over last 100 episodes: -104.64825074777391
# Episode 3700 completed. Moving Average Reward over last 100 episodes: -111.07454655061188
# Episode 3750 completed. Moving Average Reward over last 100 episodes: -100.60848705842236
# Episode 3800 completed. Moving Average Reward over last 100 episodes: -95.2808703607402
# Episode 3850 completed. Moving Average Reward over last 100 episodes: -89.33124750676981
# Episode 3900 completed. Moving Average Reward over last 100 episodes: -83.19865722853088
# Episode 3950 completed. Moving Average Reward over last 100 episodes: -98.37605388711097
# Episode 4000 completed. Moving Average Reward over last 100 episodes: -98.98129632038524
# Episode 4050 completed. Moving Average Reward over last 100 episodes: -97.89091623209728
# Episode 4100 completed. Moving Average Reward over last 100 episodes: -100.28957504664562
# Episode 4150 completed. Moving Average Reward over last 100 episodes: -93.26980368957858
# Episode 4200 completed. Moving Average Reward over last 100 episodes: -101.91494421173542
# Episode 4250 completed. Moving Average Reward over last 100 episodes: -112.22784594514
# Episode 4300 completed. Moving Average Reward over last 100 episodes: -109.85382214901888
# Episode 4350 completed. Moving Average Reward over last 100 episodes: -105.27511867108409
# Episode 4400 completed. Moving Average Reward over last 100 episodes: -106.44121342564483
# Episode 4450 completed. Moving Average Reward over last 100 episodes: -107.72411164866674
# Episode 4500 completed. Moving Average Reward over last 100 episodes: -106.93645083333755
# Episode 4550 completed. Moving Average Reward over last 100 episodes: -103.74359140517745
# Episode 4600 completed. Moving Average Reward over last 100 episodes: -103.1553086018695
# Episode 4650 completed. Moving Average Reward over last 100 episodes: -105.83622156607166
# Episode 4700 completed. Moving Average Reward over last 100 episodes: -100.28643937288994
# Episode 4750 completed. Moving Average Reward over last 100 episodes: -90.69266044789669
# Episode 4800 completed. Moving Average Reward over last 100 episodes: -89.36474505905318
# Episode 4850 completed. Moving Average Reward over last 100 episodes: -101.6179674467247
# Episode 4900 completed. Moving Average Reward over last 100 episodes: -111.56320298526862
# Episode 4950 completed. Moving Average Reward over last 100 episodes: -96.99636177754999
# Episode 5000 completed. Moving Average Reward over last 100 episodes: -92.83910090754244
# Episode 5050 completed. Moving Average Reward over last 100 episodes: -100.6337090763044
# Episode 5100 completed. Moving Average Reward over last 100 episodes: -99.73560599626582
# Episode 5150 completed. Moving Average Reward over last 100 episodes: -94.69033169557042
# Episode 5200 completed. Moving Average Reward over last 100 episodes: -74.1253644121468
# Episode 5250 completed. Moving Average Reward over last 100 episodes: -83.25800358037614
# Episode 5300 completed. Moving Average Reward over last 100 episodes: -104.77702821559578
# Episode 5350 completed. Moving Average Reward over last 100 episodes: -104.63670223929347
# Episode 5400 completed. Moving Average Reward over last 100 episodes: -110.49605417294782
# Episode 5450 completed. Moving Average Reward over last 100 episodes: -114.37907492206172
# Episode 5500 completed. Moving Average Reward over last 100 episodes: -99.98068997943048
# Episode 5550 completed. Moving Average Reward over last 100 episodes: -95.59560682306441
# Episode 5600 completed. Moving Average Reward over last 100 episodes: -108.43664373030735
# Episode 5650 completed. Moving Average Reward over last 100 episodes: -111.58006375305072
# Episode 5700 completed. Moving Average Reward over last 100 episodes: -107.31183145055793
# Episode 5750 completed. Moving Average Reward over last 100 episodes: -106.71907376196668
# Episode 5800 completed. Moving Average Reward over last 100 episodes: -107.76490993837379
# Episode 5850 completed. Moving Average Reward over last 100 episodes: -103.51836096407844
# Episode 5900 completed. Moving Average Reward over last 100 episodes: -107.95336423264524
# Episode 5950 completed. Moving Average Reward over last 100 episodes: -119.13635117346794
# Episode 6000 completed. Moving Average Reward over last 100 episodes: -112.6407653242658
# Episode 6050 completed. Moving Average Reward over last 100 episodes: -100.04034541230679
# Episode 6100 completed. Moving Average Reward over last 100 episodes: -96.60675870358115
# Episode 6150 completed. Moving Average Reward over last 100 episodes: -106.61031103430084
# Episode 6200 completed. Moving Average Reward over last 100 episodes: -107.21686283643662
# Episode 6250 completed. Moving Average Reward over last 100 episodes: -104.06716591143997
# Episode 6300 completed. Moving Average Reward over last 100 episodes: -105.07278226998316
# Episode 6350 completed. Moving Average Reward over last 100 episodes: -99.88960672707012
# Episode 6400 completed. Moving Average Reward over last 100 episodes: -99.15190352341402
# Episode 6450 completed. Moving Average Reward over last 100 episodes: -98.51135435190632
# Episode 6500 completed. Moving Average Reward over last 100 episodes: -105.47523722134252
# Episode 6550 completed. Moving Average Reward over last 100 episodes: -110.0158554557215
# Episode 6600 completed. Moving Average Reward over last 100 episodes: -95.12573861671444
# Episode 6650 completed. Moving Average Reward over last 100 episodes: -75.97802163377735
# Episode 6700 completed. Moving Average Reward over last 100 episodes: -84.69061829302038
# Episode 6750 completed. Moving Average Reward over last 100 episodes: -97.02036219154023
# Episode 6800 completed. Moving Average Reward over last 100 episodes: -109.62892924738293
# Episode 6850 completed. Moving Average Reward over last 100 episodes: -115.82540656659904
# Episode 6900 completed. Moving Average Reward over last 100 episodes: -106.17000715832074
# Episode 6950 completed. Moving Average Reward over last 100 episodes: -94.41100126205292
# Episode 7000 completed. Moving Average Reward over last 100 episodes: -88.23102121982427
# Episode 7050 completed. Moving Average Reward over last 100 episodes: -93.79837420171472
# Episode 7100 completed. Moving Average Reward over last 100 episodes: -94.6624424880189
# Episode 7150 completed. Moving Average Reward over last 100 episodes: -90.49262503844136
# Episode 7200 completed. Moving Average Reward over last 100 episodes: -102.96517489891677
# Episode 7250 completed. Moving Average Reward over last 100 episodes: -103.62553515861755
# Episode 7300 completed. Moving Average Reward over last 100 episodes: -99.51351989950594
# Episode 7350 completed. Moving Average Reward over last 100 episodes: -108.36558396821576
# Episode 7400 completed. Moving Average Reward over last 100 episodes: -92.39681475706428
# Episode 7450 completed. Moving Average Reward over last 100 episodes: -99.51213792193248
# Episode 7500 completed. Moving Average Reward over last 100 episodes: -107.08825637071402
# Episode 7550 completed. Moving Average Reward over last 100 episodes: -95.97154237012512
# Episode 7600 completed. Moving Average Reward over last 100 episodes: -95.3685890365427
# Episode 7650 completed. Moving Average Reward over last 100 episodes: -95.96251043107088
# Episode 7700 completed. Moving Average Reward over last 100 episodes: -98.49645733397365
# Episode 7750 completed. Moving Average Reward over last 100 episodes: -104.89331705815525
# Episode 7800 completed. Moving Average Reward over last 100 episodes: -92.25903821503081
# Episode 7850 completed. Moving Average Reward over last 100 episodes: -83.69798645449274
# Episode 7900 completed. Moving Average Reward over last 100 episodes: -96.05019346403027
# Episode 7950 completed. Moving Average Reward over last 100 episodes: -92.80758422749395
# Episode 8000 completed. Moving Average Reward over last 100 episodes: -101.57955200707535
# Episode 8050 completed. Moving Average Reward over last 100 episodes: -105.81501406582618
# Episode 8100 completed. Moving Average Reward over last 100 episodes: -103.19167486493527
# Episode 8150 completed. Moving Average Reward over last 100 episodes: -104.39663430503326
# Episode 8200 completed. Moving Average Reward over last 100 episodes: -97.41744102550328
# Episode 8250 completed. Moving Average Reward over last 100 episodes: -89.33239744537927
# Episode 8300 completed. Moving Average Reward over last 100 episodes: -85.2531490495532
# Episode 8350 completed. Moving Average Reward over last 100 episodes: -86.40416520127725
# Episode 8400 completed. Moving Average Reward over last 100 episodes: -96.1637830784759
# Episode 8450 completed. Moving Average Reward over last 100 episodes: -98.08629181148346
# Episode 8500 completed. Moving Average Reward over last 100 episodes: -84.8675132698714
# Episode 8550 completed. Moving Average Reward over last 100 episodes: -86.49293822894906
# Episode 8600 completed. Moving Average Reward over last 100 episodes: -92.8341062139683
# Episode 8650 completed. Moving Average Reward over last 100 episodes: -103.6164254183251
# Episode 8700 completed. Moving Average Reward over last 100 episodes: -104.81463923142917
# Episode 8750 completed. Moving Average Reward over last 100 episodes: -100.36892785240839
# Episode 8800 completed. Moving Average Reward over last 100 episodes: -100.5345801754271
# Episode 8850 completed. Moving Average Reward over last 100 episodes: -101.0288037998257
# Episode 8900 completed. Moving Average Reward over last 100 episodes: -100.5517296537859
# Episode 8950 completed. Moving Average Reward over last 100 episodes: -87.99420814091009
# Episode 9000 completed. Moving Average Reward over last 100 episodes: -88.95458610091215
# Episode 9050 completed. Moving Average Reward over last 100 episodes: -100.09977385244923
# Episode 9100 completed. Moving Average Reward over last 100 episodes: -95.94579434384501
# Episode 9150 completed. Moving Average Reward over last 100 episodes: -80.12984564354453
# Episode 9200 completed. Moving Average Reward over last 100 episodes: -82.34925012214059
# Episode 9250 completed. Moving Average Reward over last 100 episodes: -87.50493292396901
# Episode 9300 completed. Moving Average Reward over last 100 episodes: -94.62820431256225
# Episode 9350 completed. Moving Average Reward over last 100 episodes: -94.6948741634121
# Episode 9400 completed. Moving Average Reward over last 100 episodes: -77.83326357211294
# Episode 9450 completed. Moving Average Reward over last 100 episodes: -86.84407296157788
# Episode 9500 completed. Moving Average Reward over last 100 episodes: -85.65469762774676
# Episode 9550 completed. Moving Average Reward over last 100 episodes: -71.95339973661288
# Episode 9600 completed. Moving Average Reward over last 100 episodes: -81.71833627909147
# Episode 9650 completed. Moving Average Reward over last 100 episodes: -94.10375026709086
# Episode 9700 completed. Moving Average Reward over last 100 episodes: -96.9517580494216
# Episode 9750 completed. Moving Average Reward over last 100 episodes: -89.24399684324503
# Episode 9800 completed. Moving Average Reward over last 100 episodes: -81.98258499888613
# Episode 9850 completed. Moving Average Reward over last 100 episodes: -92.52996847681128
# Episode 9900 completed. Moving Average Reward over last 100 episodes: -92.00844809034308
# Episode 9950 completed. Moving Average Reward over last 100 episodes: -89.89658380667602
# Episode 10000 completed. Moving Average Reward over last 100 episodes: -93.43961851256576

# %%
n_test_episodes = 100
total_rewards = 0.0

for episode in range(n_test_episodes):
    state, _ = env.reset()
    state = discretize_state(state)
    done = False
    episode_reward = 0.0
    
    while not done:
        action = np.argmax(Q[state])  # action with the highest Q-value
        next_state, reward, terminated, truncated, _ = env.step(action)
        next_state = discretize_state(next_state)
        
        episode_reward += reward
        state = next_state
        done = terminated or truncated
    
    total_rewards += episode_reward

average_reward = total_rewards / n_test_episodes
print(f"Average reward over {n_test_episodes} test episodes: {average_reward}")
# Out:
# Average reward over 100 test episodes: -92.99059346527241

# %% [markdown]
# ## (f) (10 points)
# Again, train a policy and evaluate it. Plot a curve showing the progress of training,
# i.e., the quality of the policy over the number of game steps (frames) trained on. Interpret the
# learning curve. What can be said about the performance of the algorithm with these parameters
# and this state representation on the given task? How does this compare to the performance of
# Monte-Carlo?

# %%
plt.figure(figsize=(10, 6))
plt.plot(episode_numbers, moving_average_rewards, label='Q Agent', marker='o')
plt.axhline(y=random_avg_reward, color='r', linestyle='--', label='Random Agent')
plt.xlabel('Episodes')
plt.ylabel('Average Reward')
plt.title('Performance Comparison: Q-learning Agent vs Random Agent')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## (g) (20 points)
# Pick one of the algorithms and try to tune the parameters as well as the discretization in order to improve the performance. Interpret the results of the experiments. Do the
# optimal parameter values depend on each other?
#
# Hint: The paper https://arxiv.org/abs/2011.11850 might give some useful information
# about reasonable parameter values.

# %%
#Observation High
# [1.5 1.5 5. 5. 3.14 5. 1. 1. ]

# Observation Low
# [-1.5 -1.5 -5. -5. -3.14 -5. -0. -0. ]

def discretize_state(state, n=5):
    number_of_buckets = (n, n, n, n, n, n, 2, 2)  # buckets in each dimension
    state_value_bounds = list(zip(env.observation_space.low, env.observation_space.high))

    state_value_bounds[0] = [-1, 1]  # Position x
    state_value_bounds[1] = [-1, 1]  # Position y
    state_value_bounds[2] = [-1, 1]  # vel x
    state_value_bounds[3] = [-1, 1]  # vel y
    state_value_bounds[4] = [-1, 1]  # angle
    state_value_bounds[5] = [-1, 1]  # angular vel
    state_value_bounds[6] = [0, 1]   # leg1
    state_value_bounds[7] = [0, 1]   # leg2

    bucket_indexes = []
    for i in range(len(state)):
        if state[i] <= state_value_bounds[i][0]:
            bucket_index = 0
        elif state[i] >= state_value_bounds[i][1]:
            bucket_index = number_of_buckets[i] - 1
        else:
            bound_width = state_value_bounds[i][1] - state_value_bounds[i][0]
            offset = (number_of_buckets[i] - 1) * state_value_bounds[i][0] / bound_width
            scaling = (number_of_buckets[i] - 1) / bound_width
            bucket_index = int(round(scaling * state[i] - offset))
        bucket_indexes.append(bucket_index)
    return tuple(bucket_indexes)

# Test the updated function
# Reset the environment to get an initial state
initial_state, _ = env.reset()

# Discretize the initial state using the new function
discrete_initial_state = discretize_state(initial_state)

print(f"Initial state: {initial_state}")
print(f"Discrete initial state: {discrete_initial_state}")
# Out:
# Initial state: [-0.00619745  1.4195114  -0.6277557   0.3818279   0.00718815  0.14219607
#   0.          0.        ]
# Discrete initial state: (4, 9, 2, 6, 5, 5, 0, 0)

# %%
env = gym.make("LunarLander-v2")

n_episodes = 10000
timesteps=1000
epsilon = 0.1
alpha = 0.25
gamma = 0.99
step_size = 200  
moving_average_window = 100  

Q = defaultdict(lambda: np.zeros(env.action_space.n))

def choose_action(state):
    if np.random.rand() < epsilon:
        return np.random.choice(env.action_space.n)
    else:
        return np.argmax(Q[state])

episode_numbers = []
moving_average_rewards = []

last_n_rewards = []  # To keep the rewards of the last MA episodes

for episode in range(1, n_episodes + 1):
    episode_rewards = 0
    state, _ = env.reset()
    state = discretize_state(state)
    
    done = False
    episode_states_actions = []
    episode_rewards = []
    
    for _ in range(timesteps):
        action = choose_action(state)
        next_state, reward, terminated, truncated, _ = env.step(action)
        next_state = discretize_state(next_state)
        
        # Update Q-table for Q(s,a)
        Q[state][action] = Q[state][action]  + alpha * (reward + gamma * np.argmax(Q[next_state]) - Q[state][action])

        episode_states_actions.append((state, action))
        episode_rewards.append(reward)
        
        state = next_state
        done = terminated or truncated

        if done:
            break

    total_episode_reward = sum(episode_rewards)
    last_n_rewards.append(total_episode_reward)
    
    if len(last_n_rewards) > moving_average_window:
        last_n_rewards.pop(0)
    
    moving_average = np.mean(last_n_rewards)
    
    if episode % step_size == 0:
        episode_numbers.append(episode)
        moving_average_rewards.append(moving_average)
        print(f"Episode {episode} completed. Moving Average Reward over last {moving_average_window} episodes: {moving_average}")
# Out:
# Episode 50 completed. Moving Average Reward over last 100 episodes: -175.8120961153041
# Episode 100 completed. Moving Average Reward over last 100 episodes: -176.2330549727646
# Episode 150 completed. Moving Average Reward over last 100 episodes: -164.87806253963456
# Episode 200 completed. Moving Average Reward over last 100 episodes: -135.17344140592317
# Episode 250 completed. Moving Average Reward over last 100 episodes: -125.81103023085048
# Episode 300 completed. Moving Average Reward over last 100 episodes: -138.4630843130068
# Episode 350 completed. Moving Average Reward over last 100 episodes: -125.48935593732769
# Episode 400 completed. Moving Average Reward over last 100 episodes: -126.42513718483934
# Episode 450 completed. Moving Average Reward over last 100 episodes: -127.46813527179592
# Episode 500 completed. Moving Average Reward over last 100 episodes: -119.60517800622034
# Episode 550 completed. Moving Average Reward over last 100 episodes: -113.66306771200107
# Episode 600 completed. Moving Average Reward over last 100 episodes: -104.67565564894934
# Episode 650 completed. Moving Average Reward over last 100 episodes: -112.61659183897143
# Episode 700 completed. Moving Average Reward over last 100 episodes: -130.8558490753908
# Episode 750 completed. Moving Average Reward over last 100 episodes: -139.21320999663115
# Episode 800 completed. Moving Average Reward over last 100 episodes: -135.14288549861146
# Episode 850 completed. Moving Average Reward over last 100 episodes: -138.07276914298822
# Episode 900 completed. Moving Average Reward over last 100 episodes: -134.23306781127738
# Episode 950 completed. Moving Average Reward over last 100 episodes: -128.01227916390127
# Episode 1000 completed. Moving Average Reward over last 100 episodes: -120.25444578717116
# Episode 1050 completed. Moving Average Reward over last 100 episodes: -124.15615939616856
# Episode 1100 completed. Moving Average Reward over last 100 episodes: -134.37898779845034
# Episode 1150 completed. Moving Average Reward over last 100 episodes: -128.36796434945308
# Episode 1200 completed. Moving Average Reward over last 100 episodes: -118.07374692984446
# Episode 1250 completed. Moving Average Reward over last 100 episodes: -125.04536981753068
# Episode 1300 completed. Moving Average Reward over last 100 episodes: -124.99722836567233
# Episode 1350 completed. Moving Average Reward over last 100 episodes: -112.83704519241545
# Episode 1400 completed. Moving Average Reward over last 100 episodes: -112.27351670828077
# Episode 1450 completed. Moving Average Reward over last 100 episodes: -113.05990693877585
# Episode 1500 completed. Moving Average Reward over last 100 episodes: -116.9542343223356
# Episode 1550 completed. Moving Average Reward over last 100 episodes: -121.976666792904
# Episode 1600 completed. Moving Average Reward over last 100 episodes: -105.59713016146875
# Episode 1650 completed. Moving Average Reward over last 100 episodes: -103.83959843671181
# Episode 1700 completed. Moving Average Reward over last 100 episodes: -115.55919754149157
# Episode 1750 completed. Moving Average Reward over last 100 episodes: -114.7668980047884
# Episode 1800 completed. Moving Average Reward over last 100 episodes: -109.29200459636948
# Episode 1850 completed. Moving Average Reward over last 100 episodes: -111.90601100318442
# Episode 1900 completed. Moving Average Reward over last 100 episodes: -119.55585606509672
# Episode 1950 completed. Moving Average Reward over last 100 episodes: -111.11616297045924
# Episode 2000 completed. Moving Average Reward over last 100 episodes: -97.27773742657014
# Episode 2050 completed. Moving Average Reward over last 100 episodes: -90.16302225064568
# Episode 2100 completed. Moving Average Reward over last 100 episodes: -96.31327497739008
# Episode 2150 completed. Moving Average Reward over last 100 episodes: -91.56516993956717
# Episode 2200 completed. Moving Average Reward over last 100 episodes: -89.47182808111938
# Episode 2250 completed. Moving Average Reward over last 100 episodes: -102.76849748467866
# Episode 2300 completed. Moving Average Reward over last 100 episodes: -94.04650265138683
# Episode 2350 completed. Moving Average Reward over last 100 episodes: -100.59962594129257
# Episode 2400 completed. Moving Average Reward over last 100 episodes: -116.36084023679855
# Episode 2450 completed. Moving Average Reward over last 100 episodes: -107.47955243693882
# Episode 2500 completed. Moving Average Reward over last 100 episodes: -98.98480869913766
# Episode 2550 completed. Moving Average Reward over last 100 episodes: -101.03469007784395
# Episode 2600 completed. Moving Average Reward over last 100 episodes: -119.77576885909716
# Episode 2650 completed. Moving Average Reward over last 100 episodes: -119.56654981149696
# Episode 2700 completed. Moving Average Reward over last 100 episodes: -97.97904570169543
# Episode 2750 completed. Moving Average Reward over last 100 episodes: -89.66758553427111
# Episode 2800 completed. Moving Average Reward over last 100 episodes: -82.3598691878622
# Episode 2850 completed. Moving Average Reward over last 100 episodes: -97.82806672872837
# Episode 2900 completed. Moving Average Reward over last 100 episodes: -125.07116849144228
# Episode 2950 completed. Moving Average Reward over last 100 episodes: -118.38697996565938
# Episode 3000 completed. Moving Average Reward over last 100 episodes: -111.98900431361771
# Episode 3050 completed. Moving Average Reward over last 100 episodes: -106.66401854184579
# Episode 3100 completed. Moving Average Reward over last 100 episodes: -95.3569707461221
# Episode 3150 completed. Moving Average Reward over last 100 episodes: -111.04913145386274
# Episode 3200 completed. Moving Average Reward over last 100 episodes: -104.23635295325414
# Episode 3250 completed. Moving Average Reward over last 100 episodes: -91.4650021224438
# Episode 3300 completed. Moving Average Reward over last 100 episodes: -96.02058000201707
# Episode 3350 completed. Moving Average Reward over last 100 episodes: -88.09140094131202
# Episode 3400 completed. Moving Average Reward over last 100 episodes: -85.84086250750215
# Episode 3450 completed. Moving Average Reward over last 100 episodes: -83.64627834655957
# Episode 3500 completed. Moving Average Reward over last 100 episodes: -91.24401509796684
# Episode 3550 completed. Moving Average Reward over last 100 episodes: -97.26834280091822
# Episode 3600 completed. Moving Average Reward over last 100 episodes: -94.19021128753776
# Episode 3650 completed. Moving Average Reward over last 100 episodes: -104.64037775878671
# Episode 3700 completed. Moving Average Reward over last 100 episodes: -112.3924900738601
# Episode 3750 completed. Moving Average Reward over last 100 episodes: -99.29668596782838
# Episode 3800 completed. Moving Average Reward over last 100 episodes: -95.59220305748141
# Episode 3850 completed. Moving Average Reward over last 100 episodes: -98.27392379220174
# Episode 3900 completed. Moving Average Reward over last 100 episodes: -99.04770756838329
# Episode 3950 completed. Moving Average Reward over last 100 episodes: -92.4988530583602
# Episode 4000 completed. Moving Average Reward over last 100 episodes: -97.33965085458738
# Episode 4050 completed. Moving Average Reward over last 100 episodes: -105.55607053483068
# Episode 4100 completed. Moving Average Reward over last 100 episodes: -85.9208063469365
# Episode 4150 completed. Moving Average Reward over last 100 episodes: -81.68944694102622
# Episode 4200 completed. Moving Average Reward over last 100 episodes: -96.83711166859557
# Episode 4250 completed. Moving Average Reward over last 100 episodes: -99.50780084261392
# Episode 4300 completed. Moving Average Reward over last 100 episodes: -93.43132915324136
# Episode 4350 completed. Moving Average Reward over last 100 episodes: -98.03827332753688
# Episode 4400 completed. Moving Average Reward over last 100 episodes: -109.2748584368081
# Episode 4450 completed. Moving Average Reward over last 100 episodes: -111.8203581146695
# Episode 4500 completed. Moving Average Reward over last 100 episodes: -101.5337262555554
# Episode 4550 completed. Moving Average Reward over last 100 episodes: -100.12725953343471
# Episode 4600 completed. Moving Average Reward over last 100 episodes: -96.08471074988222
# Episode 4650 completed. Moving Average Reward over last 100 episodes: -85.15554335795176
# Episode 4700 completed. Moving Average Reward over last 100 episodes: -80.78602830894489
# Episode 4750 completed. Moving Average Reward over last 100 episodes: -86.28893445356776
# Episode 4800 completed. Moving Average Reward over last 100 episodes: -91.55758363886031
# Episode 4850 completed. Moving Average Reward over last 100 episodes: -85.69711904843616
# Episode 4900 completed. Moving Average Reward over last 100 episodes: -93.95964977053364
# Episode 4950 completed. Moving Average Reward over last 100 episodes: -93.37531236062713
# Episode 5000 completed. Moving Average Reward over last 100 episodes: -88.23946434971958
# Episode 5050 completed. Moving Average Reward over last 100 episodes: -96.8134211792542
# Episode 5100 completed. Moving Average Reward over last 100 episodes: -95.09062774234731
# Episode 5150 completed. Moving Average Reward over last 100 episodes: -97.23630964457827
# Episode 5200 completed. Moving Average Reward over last 100 episodes: -99.2897972810148
# Episode 5250 completed. Moving Average Reward over last 100 episodes: -104.47254971685177
# Episode 5300 completed. Moving Average Reward over last 100 episodes: -104.04922168747633
# Episode 5350 completed. Moving Average Reward over last 100 episodes: -97.07124102198544
# Episode 5400 completed. Moving Average Reward over last 100 episodes: -101.1221976961156
# Episode 5450 completed. Moving Average Reward over last 100 episodes: -94.59010967227117
# Episode 5500 completed. Moving Average Reward over last 100 episodes: -97.72925038938904
# Episode 5550 completed. Moving Average Reward over last 100 episodes: -98.55501624872488
# Episode 5600 completed. Moving Average Reward over last 100 episodes: -92.33344152022886
# Episode 5650 completed. Moving Average Reward over last 100 episodes: -101.36556093774341
# Episode 5700 completed. Moving Average Reward over last 100 episodes: -104.93525957565478
# Episode 5750 completed. Moving Average Reward over last 100 episodes: -99.22884956979091
# Episode 5800 completed. Moving Average Reward over last 100 episodes: -87.61818137629174
# Episode 5850 completed. Moving Average Reward over last 100 episodes: -96.31568776643226
# Episode 5900 completed. Moving Average Reward over last 100 episodes: -96.05338549924764
# Episode 5950 completed. Moving Average Reward over last 100 episodes: -90.15346901977972
# Episode 6000 completed. Moving Average Reward over last 100 episodes: -110.07138150080357
# Episode 6050 completed. Moving Average Reward over last 100 episodes: -112.29036108754808
# Episode 6100 completed. Moving Average Reward over last 100 episodes: -105.44981685314566
# Episode 6150 completed. Moving Average Reward over last 100 episodes: -89.57832571454165
# Episode 6200 completed. Moving Average Reward over last 100 episodes: -88.43191354280691
# Episode 6250 completed. Moving Average Reward over last 100 episodes: -89.65570964373079
# Episode 6300 completed. Moving Average Reward over last 100 episodes: -79.10581523155011
# Episode 6350 completed. Moving Average Reward over last 100 episodes: -88.92832545053639
# Episode 6400 completed. Moving Average Reward over last 100 episodes: -87.36858968373664
# Episode 6450 completed. Moving Average Reward over last 100 episodes: -99.98098219032723
# Episode 6500 completed. Moving Average Reward over last 100 episodes: -103.11600448071731
# Episode 6550 completed. Moving Average Reward over last 100 episodes: -87.57160194284992
# Episode 6600 completed. Moving Average Reward over last 100 episodes: -94.15739589853374
# Episode 6650 completed. Moving Average Reward over last 100 episodes: -93.22859804878284
# Episode 6700 completed. Moving Average Reward over last 100 episodes: -93.35052329445043
# Episode 6750 completed. Moving Average Reward over last 100 episodes: -88.86513616275475
# Episode 6800 completed. Moving Average Reward over last 100 episodes: -95.80957547940078
# Episode 6850 completed. Moving Average Reward over last 100 episodes: -95.95861482623768
# Episode 6900 completed. Moving Average Reward over last 100 episodes: -82.19799401412187
# Episode 6950 completed. Moving Average Reward over last 100 episodes: -88.6875168283055
# Episode 7000 completed. Moving Average Reward over last 100 episodes: -94.0869748875492
# Episode 7050 completed. Moving Average Reward over last 100 episodes: -90.06936211401403
# Episode 7100 completed. Moving Average Reward over last 100 episodes: -88.52440943066567
# Episode 7150 completed. Moving Average Reward over last 100 episodes: -100.44929336904683
# Episode 7200 completed. Moving Average Reward over last 100 episodes: -98.68734521136496
# Episode 7250 completed. Moving Average Reward over last 100 episodes: -100.69906062217315
# Episode 7300 completed. Moving Average Reward over last 100 episodes: -113.63706722126953
# Episode 7350 completed. Moving Average Reward over last 100 episodes: -103.5963729978161
# Episode 7400 completed. Moving Average Reward over last 100 episodes: -100.98602660708946
# Episode 7450 completed. Moving Average Reward over last 100 episodes: -96.30137638176309
# Episode 7500 completed. Moving Average Reward over last 100 episodes: -94.44420542534581
# Episode 7550 completed. Moving Average Reward over last 100 episodes: -100.46188560858711
# Episode 7600 completed. Moving Average Reward over last 100 episodes: -91.9609483980387
# Episode 7650 completed. Moving Average Reward over last 100 episodes: -83.57819449335626
# Episode 7700 completed. Moving Average Reward over last 100 episodes: -85.07427814504052
# Episode 7750 completed. Moving Average Reward over last 100 episodes: -89.81074439826824
# Episode 7800 completed. Moving Average Reward over last 100 episodes: -76.07482365423137
# Episode 7850 completed. Moving Average Reward over last 100 episodes: -83.6955890114934
# Episode 7900 completed. Moving Average Reward over last 100 episodes: -98.38495996416479
# Episode 7950 completed. Moving Average Reward over last 100 episodes: -100.11916766447769
# Episode 8000 completed. Moving Average Reward over last 100 episodes: -100.9473039835566
# Episode 8050 completed. Moving Average Reward over last 100 episodes: -90.88172732777424
# Episode 8100 completed. Moving Average Reward over last 100 episodes: -92.04719886607039
# Episode 8150 completed. Moving Average Reward over last 100 episodes: -92.27968474257642
# Episode 8200 completed. Moving Average Reward over last 100 episodes: -93.90909997846933
# Episode 8250 completed. Moving Average Reward over last 100 episodes: -88.30763566843025
# Episode 8300 completed. Moving Average Reward over last 100 episodes: -72.04255433823477
# Episode 8350 completed. Moving Average Reward over last 100 episodes: -90.80324713272559
# Episode 8400 completed. Moving Average Reward over last 100 episodes: -98.95640621915493
# Episode 8450 completed. Moving Average Reward over last 100 episodes: -82.89953822320169
# Episode 8500 completed. Moving Average Reward over last 100 episodes: -82.12279108501163
# Episode 8550 completed. Moving Average Reward over last 100 episodes: -89.08560440850454
# Episode 8600 completed. Moving Average Reward over last 100 episodes: -86.36211218124373
# Episode 8650 completed. Moving Average Reward over last 100 episodes: -81.37751229448673
# Episode 8700 completed. Moving Average Reward over last 100 episodes: -81.18416631684256
# Episode 8750 completed. Moving Average Reward over last 100 episodes: -90.42338662759038
# Episode 8800 completed. Moving Average Reward over last 100 episodes: -97.93652174424331
# Episode 8850 completed. Moving Average Reward over last 100 episodes: -84.75273549189873
# Episode 8900 completed. Moving Average Reward over last 100 episodes: -75.97974199240036
# Episode 8950 completed. Moving Average Reward over last 100 episodes: -80.92025772258842
# Episode 9000 completed. Moving Average Reward over last 100 episodes: -90.2622533038572
# Episode 9050 completed. Moving Average Reward over last 100 episodes: -85.12039258892273
# Episode 9100 completed. Moving Average Reward over last 100 episodes: -87.40806834647238
# Episode 9150 completed. Moving Average Reward over last 100 episodes: -79.32735232040662
# Episode 9200 completed. Moving Average Reward over last 100 episodes: -78.62597570682142
# Episode 9250 completed. Moving Average Reward over last 100 episodes: -100.52920325539182
# Episode 9300 completed. Moving Average Reward over last 100 episodes: -79.28130414650931
# Episode 9350 completed. Moving Average Reward over last 100 episodes: -80.48154838467603
# Episode 9400 completed. Moving Average Reward over last 100 episodes: -86.24545546554498
# Episode 9450 completed. Moving Average Reward over last 100 episodes: -73.52516241516331
# Episode 9500 completed. Moving Average Reward over last 100 episodes: -72.11617015952397
# Episode 9550 completed. Moving Average Reward over last 100 episodes: -79.72695369689438
# Episode 9600 completed. Moving Average Reward over last 100 episodes: -94.63194966535247
# Episode 9650 completed. Moving Average Reward over last 100 episodes: -93.353056343097
# Episode 9700 completed. Moving Average Reward over last 100 episodes: -93.43900197767789
# Episode 9750 completed. Moving Average Reward over last 100 episodes: -105.86859400035083
# Episode 9800 completed. Moving Average Reward over last 100 episodes: -103.78465900970646
# Episode 9850 completed. Moving Average Reward over last 100 episodes: -102.23937772058339
# Episode 9900 completed. Moving Average Reward over last 100 episodes: -109.83471571218004
# Episode 9950 completed. Moving Average Reward over last 100 episodes: -100.02583633198314
# Episode 10000 completed. Moving Average Reward over last 100 episodes: -94.163353309096

# %%
plt.figure(figsize=(10, 6))
plt.plot(episode_numbers, moving_average_rewards, label='Q Agent', marker='o')
plt.axhline(y=random_avg_reward, color='r', linestyle='--', label='Random Agent')
plt.xlabel('Episodes')
plt.ylabel('Average Reward')
plt.title('Performance Comparison: Q-learning Agent vs Random Agent')
plt.legend()
plt.grid(True)
plt.show()

# %%
n_test_episodes = 100
total_rewards = 0.0

for episode in range(n_test_episodes):
    state, _ = env.reset()
    state = discretize_state(state)
    done = False
    episode_reward = 0.0
    
    while not done:
        action = np.argmax(Q[state])  # action with the highest Q-value
        next_state, reward, terminated, truncated, _ = env.step(action)
        next_state = discretize_state(next_state)
        
        episode_reward += reward
        state = next_state
        done = terminated or truncated
    
    total_rewards += episode_reward

average_reward = total_rewards / n_test_episodes
print(f"Average reward over {n_test_episodes} test episodes: {average_reward}")
# Out:
# Average reward over 100 test episodes: -93.76232069664327

# %% [markdown]
# ## (h) (10 points)
# Once you have learned a good policy, check whether it is robust enough to handle
# small variations in the environment. One way to do this relatively easily is to enable wind
# (enable_wind and wind_power parameters in textttgym.make) and measure the performance
# of the policy with different amounts of wind.

# %%
n_episodes = 10000
gamma = 0.999
step_size = 200  
moving_average_window = 100  

fig, axs = plt.subplots(3, 1, figsize=(18, 10))

for idx, wind_strength in enumerate([5, 10, 15]):
    env = gym.make("LunarLander-v2", enable_wind=True, wind_power=wind_strength)

    Q = defaultdict(lambda: np.zeros(env.action_space.n))
    N = defaultdict(lambda: np.zeros(env.action_space.n))

    episode_numbers = []
    moving_average_rewards = []
    greedy_rewards = []
    greedy_episodes = []
    last_n_rewards = []
    
    for episode in range(1, n_episodes + 1):
        curr_epsilon = max(0.01, min(1, 1.0 - math.log10((episode + 1) / (n_episodes * 0.1))))
        
        state, _ = env.reset()
        state = discretize_state(state)
        
        done = False
        episode_states_actions = []
        episode_rewards = []
        
        while not done:
            action = choose_action(state, curr_epsilon)
            next_state, reward, terminated, truncated, _ = env.step(action)
            next_state = discretize_state(next_state)
            
            episode_states_actions.append((state, action))
            episode_rewards.append(reward)
            
            state = next_state

            done = terminated or truncated

        G = 0
        for t in reversed(range(len(episode_states_actions))):
            state, action = episode_states_actions[t]
            reward = episode_rewards[t]
            
            G = gamma * G + reward
            N[state][action] += 1
            
            Q[state][action] += (G - Q[state][action]) / N[state][action]
        
        total_episode_reward = sum(episode_rewards)
        last_n_rewards.append(total_episode_reward)
        
        if len(last_n_rewards) > moving_average_window:
            last_n_rewards.pop(0)
        
        moving_average = np.mean(last_n_rewards)
        
        if episode % step_size == 0:
            episode_numbers.append(episode)
            moving_average_rewards.append(moving_average)
            
        if episode % 500 == 0:
            avg_reward = evaluate_greedy_policy(env, Q)
            greedy_rewards.append(avg_reward)
            greedy_episodes.append(episode)

    axs[idx].plot(episode_numbers, moving_average_rewards, label='MC Agent (Training)', marker='o')
    axs[idx].plot(greedy_episodes, greedy_rewards, label='MC Agent (Greedy)', marker='x')
    axs[idx].axhline(y=random_avg_reward, color='r', linestyle='--', label='Random Agent')
    axs[idx].set_title(f'Wind Strength: {wind_strength}')
    axs[idx].set_xlabel('')
    axs[idx].set_ylabel('Average Reward')
    axs[idx].legend()
    axs[idx].grid(True)

plt.show()

# %%
# Out:
# 0

# %% [markdown]
# ## (i) (50 bonus points)
# Implement Deep-Q-Learning, i.e., use a neural network as function to
# predict Q values for the actions. Compare the performance to the previous best model. Also,
# compare the run-time required for training. Note that training with Deep-Q-Learning might
# take a lot longer than training the other methods.
#
# Hint: The same paper as above might help getting a reasonable setup for the network and the
# training parameters. It is possible to make the network somewhat smaller (e.g., 2 hidden layers
# with 64 units each might do) to make training a bit less expensive.
