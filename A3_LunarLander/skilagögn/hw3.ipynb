# %% [markdown]
# # Reinforcement Learning
# # Homework 3: Sampling-Based Approaches, Function Approximation
#
# Þórir Hrafn Harðarson – thorirhh21@ru.is , Halldór Kristinsson – halldork21@ru.is

# %% [markdown]
# # 1. (Total points: 30)
# Consider the grid-world domain shown below. The possible actions are the four
# cardinal direction movements: up, down, left and right. All state transitions are deterministic.
# Moving in some direction changes the agent’s position by one square in the given direction, unless it
# bumps into a wall or hits the edge of the world, in which case the position stays unchanged. Falling
# in the hole or reaching the goal both leads to terminal states. The agent gets a reward of +10 points
# for reaching the goal state, -1 for bumping into a wall or the edge of the world, and -50 for falling
# into a hole. Future rewards are discounted at a rate of 0.9 per step.

# %% [markdown]
# ## (a) (5 points)
# What is the value of state a under the optimal policy?
# ***

# %% [markdown]
# We use the formula:
#
# $
# V(s) = R(s) + \gamma \times V(s')
# $

# %%
reward_goal = 10
reward_non_terminal = 0
discount_factor = 0.9

value_goal = reward_goal  
value_f = reward_non_terminal + discount_factor * value_goal
value_e = reward_non_terminal + discount_factor * value_f 
value_d = reward_non_terminal + discount_factor * value_e 
value_c = reward_non_terminal + discount_factor * value_d 
value_b = reward_non_terminal + discount_factor * value_c 
value_a = reward_non_terminal + discount_factor * value_b  

print(f"Value of state a under the optimal policy is: {value_a}")
# Out:
# Value of state a under the optimal policy is: 5.3144100000000005

# %% [markdown]
# ## (b) (5 points)
# Q-Learning is an Off-Policy TD control method while Sarsa is said to be On-Policy. What does that mean?
# ***

# %% [markdown]
# Firstly, one is an **Off-policy** method while the other is an **On-policy** method.
#
# **Off-policy** methods try to fit a target policy from data that is generated from another, behaviour policy
#
# **On-policy** methods update the existing policy, so the policy used for learning is the same one that is used for behaviour. Meaning the agent will learn from the policy it is actually following.
#
# **SARSA** is more cautious while **Q-learning** aims for the higher reward, even when it is risky. As we saw in the cliff walking example, SARSA chose the safe path while Q-learning aimed for the more risky path.
#
# $$ SARSA $$
# $$
# Q(s, a) \leftarrow Q(s, a) + \alpha \left[ r + \gamma Q(s', a') - Q(s, a) \right]
# $$\
# SARSA uses the action a' taken in s' for the Q-value update, making it take the penalty from falling in the hole more into account.
#
# $$ Q-Learning $$
# $$ Q(s, a) \leftarrow Q(s, a) + \alpha \left[ r + \gamma \max_{a'} Q(s', a') - Q(s, a) \right] $$
# Here we can see that the Q-value update is done using the maximum estimated future reward, even when the agent didnt take the action. This makes the algorithm optimistic as it assumes the future behaviour is greedy and risky.
#
# They major differences in the methods therefore lie in how they update their estimates and exploration vs exploitation where **SARSA** is more balanced while **Q-Learning** is inclined towards exploiting for higher rewards.

# %% [markdown]
# ## (c) (10 points)
# Suppose Sarsa and Q-Learning would be used to learn a policy for the problem
# (without fixing the episodes, but picking them using an epsilon-greedy policy). Which policies
# (preferred paths) would you expect the two algorithms to learn? Justify your answer.
# ***

# %% [markdown]
# It is likely that Q-learning will learn the optimal path (a-b-c-d-e-f), even though it is riskier, while SARSA will go around to avoid the hole, as it is much safer (a-g-h-i-j-k-l-m-n-f).
#
# Like we explain in the answer above, SARSA will recognise and take into account that following the optimal path will also make falling into the hole increasinly likely.

# %% [markdown]
# ## (d) (10 points)
# Does the value for ϵ matter for the answer of the previous question? How? (That
# is, which of the methods is affected in which way by changing ϵ?)
# ***

# %% [markdown]
# **SARSA**
# High ϵ, or more exploration means that it is more likely that we explore risky acitons and end up in the hole, since SARSA is an on-policy method, it will learn to avoid the hole in the end though. If we lower the ϵ too much the agent will behave safely but might learn not so good paths, therefore never discovering the optimal path.
#
# **Q-Learning**
# High ϵ, now the agent will explore more, taking inccreased risks, but as an off-policy method it should find the optimal policy eventually, it could take a lot of time to converge though. If we lower ϵ too much, we end up in a similar case as with SARSA, the agent might stick to suboptimal paths, never learning the best paths.
#
# One option would be to  gradually reducing ε in which case both methods will asymptotically converge to the optimal policy
#
# So the value of ϵ will affect both algorithms.

# %% [markdown]
# # 2. Deadly Triad (Total points: 20)

# %% [markdown]
# ## (a) (5 points)
# Shortly explain what is meant by ”deadly triad” when discussing reinforcement learning algorithms. (What is the problem and what causes it?)
# ***

# %% [markdown]
# The deadly triad is when all three of **Function Approximation**, **Bootsrapping** and **Off-Policy Training** are mixed together, making algorithms unstable and potentially diverge. But this is not the case when the methods are carefully balanced, using only 1 or 2 elements together, the dangers of the deadly triad can be avoided. So the problem is when we mix them all together, they become unstable and can diverge.
#
# **Function Approximation** is probably the most important element, since without it it's impossible to scale to large problems, but as in the name, are approximations.. leading to potential errors that will get propogated into our future estimates
#
# **Bootstrapping** comes in handy as its useful for data- and computational efficiency, but similar to the function approximation, we are using estimates to estimate future values, so if the estimates are off, they will spiral. Bootstrapping can also introduce higher variance into our value function updates.
#
# **Off-Policy Training** can be optional but can also be essential for advanced use cases if we are learning policies in parallel but often on-policy methods can be adequate and for instance in model-free RL we could choose SARSA instead of Q-learning.

# %% [markdown]
# ## (b) (15 points)
# Baird’s counterexample is used to illustrate a potential instability of reinforcement
# learning algorithms. Show that dropping any of the three parts of the deadly triad (function
# approximation, temporal difference learning/bootstrapping, off-policy learning) would result in
# convergence to the correct values for Baird’s counterexample.
# ***

# %% [markdown]
# If we remove **Function Approximation** then we go to a tabular setting with a finite number of states and actions. In this case each state action pair will have its own unique value.
#
# Removing **Bootstrapping** we are no longar working with estimates, which removes noise caused by potential inaccurasies, and therefore get a guarantee to converge from the law of large numbers.
#
# Dropping **Off-Policy Learning** we wont have a distribution mismatch since we wont have two policies, and the same policy is generating and updating the estimates. This will result in more stable learning and we will converge.

# %% [markdown]
# # 3. (Total points: 100)
# Consider the Lunar Lander environment from https://gymnasium.farama.org/.\
# The goal is to land a spacecraft on the moon safely (without crashing) and with as little manouvering
# as possible. The state space is 8-dimensional and consists of
# - horizontal and vertical position of the lander (x and y)
# - velocities in x and y direction
# - the angle of the lander and angular velocity
# - for both legs whether they touch the ground or not
#
#
# Your task is to use Reinforcement Learning to find a good policy for this setting.

# %% [markdown]
# ## (a) (10 points)
# Implement a purely random agent for the enviroment as a baseline to compare other
# agents to.

# %%
import gymnasium as gym

env = gym.make("LunarLander-v2")

num_episodes = 100

episode_rewards = []

for episode in range(num_episodes):
 
    observation, info = env.reset()
    total_reward = 0
    done = False
    
    while not done:
        # random action
        action = env.action_space.sample()
        
        observation, reward, terminated, truncated, info = env.step(action)
        
        # update rewards
        total_reward += reward
        
        done = terminated or truncated

    episode_rewards.append(total_reward)

env.close()

random_avg_reward = sum(episode_rewards) / num_episodes
print(f"Average Reward: {random_avg_reward}")
# Out:
# Average Reward: -179.44771827462722

# %% [markdown]
# ## (b) (10 points)
# In order to use a tabular approach for solving the problem, you need to first discretize the state space. One way to achieve that is to split each attribute (except for the boolean
# ones) evenly into n intervals each, resulting in at most 4 ∗ n
# 6 different states to consider (not
# all of those might be reachable). Implement a function that maps each state/observation to its
# discretized version. Keep n as a parameter to tune later and set n = 10 as a default.

# %%
def discretize_state(state, n=5):
    number_of_buckets = (n, n, n, n, n, n, 2, 2)  # buckets in each dimension
    state_value_bounds = list(zip(env.observation_space.low, env.observation_space.high))

    state_value_bounds[0] = [-1, 1]  # Position x
    state_value_bounds[1] = [-1, 1]  # Position y
    state_value_bounds[2] = [-1, 1]  # vel x
    state_value_bounds[3] = [-1, 1]  # vel y
    state_value_bounds[4] = [-1, 1]  # angle
    state_value_bounds[5] = [-1, 1]  # angular vel
    state_value_bounds[6] = [0, 1]   # leg1
    state_value_bounds[7] = [0, 1]   # leg2

    bucket_indexes = []
    for i in range(len(state)):
        if state[i] <= state_value_bounds[i][0]:
            bucket_index = 0
        elif state[i] >= state_value_bounds[i][1]:
            bucket_index = number_of_buckets[i] - 1
        else:
            bound_width = state_value_bounds[i][1] - state_value_bounds[i][0]
            offset = (number_of_buckets[i] - 1) * state_value_bounds[i][0] / bound_width
            scaling = (number_of_buckets[i] - 1) / bound_width
            bucket_index = int(round(scaling * state[i] - offset))
        bucket_indexes.append(bucket_index)
    return tuple(bucket_indexes)

# Test the updated function
# Reset the environment to get an initial state
initial_state, _ = env.reset()

# Discretize the initial state using the new function
discrete_initial_state = discretize_state(initial_state)

print(f"Initial state: {initial_state}")
print(f"Discrete initial state: {discrete_initial_state}")
# Out:
# Initial state: [-0.00263824  1.3983686  -0.26723537 -0.5578411   0.0030638   0.06053288
#   0.          0.        ]
# Discrete initial state: (2, 4, 1, 1, 2, 2, 0, 0)

# %% [markdown]
# ## (c) (15 points)
# Implement on-policy Monte Carlo control to learn a policy for the task. Use a
# tabular approach for storing Q(s, a)
# Use an ϵ-greedy policy with ϵ = 0.1, a learning rate of 0.1 and discount future rewards with
# 0.99.

# %%
import numpy as np
from collections import defaultdict

env = gym.make("LunarLander-v2")
n_episodes = 1000
epsilon = 0.1
alpha = 0.1
gamma = 0.99
step_size = 50  
moving_average_window = 100  

Q = defaultdict(lambda: np.zeros(env.action_space.n))
N = defaultdict(lambda: np.zeros(env.action_space.n))

episode_numbers = []
moving_average_rewards = []
last_n_rewards = []

def choose_action(state):
    if np.random.rand() < epsilon:
        return np.random.choice(env.action_space.n)
    else:
        return np.argmax(Q[state])

for episode in range(1, n_episodes + 1):
    episode_rewards = 0
    state, _ = env.reset()
    state = discretize_state(state)
    
    done = False
    episode_states_actions = []
    episode_rewards = []
    
    # simulate an episode using current policy
    while not done:
        action = choose_action(state)
        # action = np.argmax(Q[state])
        next_state, reward, terminated, truncated, _ = env.step(action)
        next_state = discretize_state(next_state)
        
        episode_states_actions.append((state, action))
        episode_rewards.append(reward)
        
        state = next_state
        done = terminated or truncated
    
    total_reward = 0
    G = 0
    for t in reversed(range(len(episode_states_actions))):
        state, action = episode_states_actions[t]
        reward = episode_rewards[t]
        total_reward += reward
        
        G = gamma * G + reward
        N[state][action] += 1
        
        Q[state][action] += (G - Q[state][action]) / N[state][action]

    total_episode_reward = sum(episode_rewards)
    last_n_rewards.append(total_episode_reward)
    
    if len(last_n_rewards) > moving_average_window:
        last_n_rewards.pop(0)
    
    moving_average = np.mean(last_n_rewards)
    
    if episode % (step_size * 4) == 0:
        episode_numbers.append(episode)
        moving_average_rewards.append(moving_average)
        print(f"Episode {episode} completed. Moving Average Reward over last {moving_average_window} episodes: {moving_average}")
# Out:
# Episode 200 completed. Moving Average Reward over last 100 episodes: -118.90314918067055
# Episode 400 completed. Moving Average Reward over last 100 episodes: -80.80333538556789
# Episode 600 completed. Moving Average Reward over last 100 episodes: -58.805568168794245
# Episode 800 completed. Moving Average Reward over last 100 episodes: -50.91580110278707
# Episode 1000 completed. Moving Average Reward over last 100 episodes: -45.42678239998109

# %%
n_test_episodes = 100
total_rewards = 0.0

for episode in range(n_test_episodes):
    state, _ = env.reset()
    state = discretize_state(state)
    done = False
    episode_reward = 0.0
    
    while not done:
        action = np.argmax(Q[state])  # action with the highest Q-value
        next_state, reward, terminated, truncated, _ = env.step(action)
        next_state = discretize_state(next_state)
        
        episode_reward += reward
        state = next_state
        done = terminated or truncated
    
    total_rewards += episode_reward

average_reward = total_rewards / n_test_episodes
print(f"Average reward over {n_test_episodes} test episodes: {average_reward}")
# Out:
# Average reward over 100 test episodes: -35.28731852527135

# %% [markdown]
# ## (d) (10 points)
# Train a policy using MC and evaluate it. Plot a curve showing the progress of
# training, for example, the quality of the policy (average return) over the number of training
# episodes. Compare the performance to a purely random agent. What can be said about the
# performance of the algorithm with these parameters and this state representation on the given
# task?

# %%
import numpy as np
from collections import defaultdict

env = gym.make("LunarLander-v2")
n_episodes = 5000
epsilon = 0.1
alpha = 0.1
gamma = 0.99
step_size = 50  
moving_average_window = 100  

Q = defaultdict(lambda: np.zeros(env.action_space.n))
N = defaultdict(lambda: np.zeros(env.action_space.n))

episode_numbers = []
moving_average_rewards = []
last_n_rewards = []

def choose_action(state):
    if np.random.rand() < epsilon:
        return np.random.choice(env.action_space.n)
    else:
        return np.argmax(Q[state])

for episode in range(1, n_episodes + 1):
    episode_rewards = 0
    state, _ = env.reset()
    state = discretize_state(state)
    
    done = False
    episode_states_actions = []
    episode_rewards = []
    
    # simulate an episode using current policy
    while not done:
        action = choose_action(state)
        # action = np.argmax(Q[state])
        next_state, reward, terminated, truncated, _ = env.step(action)
        next_state = discretize_state(next_state)
        
        episode_states_actions.append((state, action))
        episode_rewards.append(reward)
        
        state = next_state
        done = terminated or truncated
    
    total_reward = 0
    G = 0
    for t in reversed(range(len(episode_states_actions))):
        state, action = episode_states_actions[t]
        reward = episode_rewards[t]
        total_reward += reward
        
        G = gamma * G + reward
        N[state][action] += 1
        
        Q[state][action] += (G - Q[state][action]) / N[state][action]

    total_episode_reward = sum(episode_rewards)
    last_n_rewards.append(total_episode_reward)
    
    if len(last_n_rewards) > moving_average_window:
        last_n_rewards.pop(0)
    
    moving_average = np.mean(last_n_rewards)
    
    if episode % (step_size * 4) == 0:
        episode_numbers.append(episode)
        moving_average_rewards.append(moving_average)
        print(f"Episode {episode} completed. Moving Average Reward over last {moving_average_window} episodes: {moving_average}")
# Out:
# Episode 200 completed. Moving Average Reward over last 100 episodes: -88.50203450445927
# Episode 400 completed. Moving Average Reward over last 100 episodes: -64.01909023767718
# Episode 600 completed. Moving Average Reward over last 100 episodes: -59.02488358464641
# Episode 800 completed. Moving Average Reward over last 100 episodes: -49.22657149524186
# Episode 1000 completed. Moving Average Reward over last 100 episodes: -43.94262156927421
# Episode 1200 completed. Moving Average Reward over last 100 episodes: -37.389791861581735
# Episode 1400 completed. Moving Average Reward over last 100 episodes: -24.93091218079399
# Episode 1600 completed. Moving Average Reward over last 100 episodes: -20.98790194225678
# Episode 1800 completed. Moving Average Reward over last 100 episodes: -56.44489411432852
# Episode 2000 completed. Moving Average Reward over last 100 episodes: -41.02224371453847
# Episode 2200 completed. Moving Average Reward over last 100 episodes: -30.02991080212751
# Episode 2400 completed. Moving Average Reward over last 100 episodes: -34.996603138535
# Episode 2600 completed. Moving Average Reward over last 100 episodes: -25.63992539412218
# Episode 2800 completed. Moving Average Reward over last 100 episodes: -28.48547384820945
# Episode 3000 completed. Moving Average Reward over last 100 episodes: -27.896441378348264
# Episode 3200 completed. Moving Average Reward over last 100 episodes: -34.325654710483974
# Episode 3400 completed. Moving Average Reward over last 100 episodes: -9.871080409716395
# Episode 3600 completed. Moving Average Reward over last 100 episodes: -31.64991654086716
# Episode 3800 completed. Moving Average Reward over last 100 episodes: -22.337532581666906
# Episode 4000 completed. Moving Average Reward over last 100 episodes: -21.771971751255393
# Episode 4200 completed. Moving Average Reward over last 100 episodes: -25.62056803907733
# Episode 4400 completed. Moving Average Reward over last 100 episodes: -12.293557967764075
# Episode 4600 completed. Moving Average Reward over last 100 episodes: -12.519307422873785
# Episode 4800 completed. Moving Average Reward over last 100 episodes: -23.178951205961475
# Episode 5000 completed. Moving Average Reward over last 100 episodes: -17.447166289441032

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.plot(episode_numbers, moving_average_rewards, label='MC Agent', marker='o')
plt.axhline(y=random_avg_reward, color='r', linestyle='--', label='Random Agent')
plt.xlabel('Episodes')
plt.ylabel('Average Reward')
plt.title('Performance Comparison: Monet-Carlo Agent vs Random Agent')
plt.legend()
plt.grid(True)
plt.show()

# %%
n_test_episodes = 100
total_rewards = 0.0

for episode in range(n_test_episodes):
    state, _ = env.reset()
    state = discretize_state(state)
    done = False
    episode_reward = 0.0
    
    while not done:
        action = np.argmax(Q[state])  # action with the highest Q-value
        next_state, reward, terminated, truncated, _ = env.step(action)
        next_state = discretize_state(next_state)
        
        episode_reward += reward
        state = next_state
        done = terminated or truncated
    
    total_rewards += episode_reward

average_reward = total_rewards / n_test_episodes
print(f"Average reward over {n_test_episodes} test episodes: {average_reward}")
# Out:
# Average reward over 100 test episodes: -8.064147303225132

# %% [markdown]
# ## (e) (15 points)
# Implement Q-Learning to learn a policy for the task. Use the same parameters as
# for Monte-Carlo as defaults.

# %%
env = gym.make("LunarLander-v2")

n_episodes = 1000
timesteps=1000
epsilon = 0.1
alpha = 0.1
gamma = 0.99
step_size = 50  
moving_average_window = 100  

Q = defaultdict(lambda: np.zeros(env.action_space.n))

def choose_action(state):
    if np.random.rand() < epsilon:
        return np.random.choice(env.action_space.n)
    else:
        return np.argmax(Q[state])

episode_numbers = []
moving_average_rewards = []

last_n_rewards = []  # To keep the rewards of the last MA episodes

for episode in range(1, n_episodes + 1):
    episode_rewards = 0
    state, _ = env.reset()
    state = discretize_state(state)
    
    done = False
    episode_states_actions = []
    episode_rewards = []
    
    for _ in range(timesteps):
        action = choose_action(state)
        next_state, reward, terminated, truncated, _ = env.step(action)
        next_state = discretize_state(next_state)
        
        # Update Q-table for Q(s,a)
        Q[state][action] = Q[state][action]  + alpha * (reward + gamma * np.argmax(Q[next_state]) - Q[state][action])

        episode_states_actions.append((state, action))
        episode_rewards.append(reward)
        
        state = next_state
        done = terminated or truncated

        if done:
            break

    total_episode_reward = sum(episode_rewards)
    last_n_rewards.append(total_episode_reward)
    
    if len(last_n_rewards) > moving_average_window:
        last_n_rewards.pop(0)
    
    moving_average = np.mean(last_n_rewards)
    
    if episode % step_size == 0:
        episode_numbers.append(episode)
        moving_average_rewards.append(moving_average)
        print(f"Episode {episode} completed. Moving Average Reward over last {moving_average_window} episodes: {moving_average}")
# Out:
# Episode 50 completed. Moving Average Reward over last 100 episodes: -142.96615794910787
# Episode 100 completed. Moving Average Reward over last 100 episodes: -145.3259059192822
# Episode 150 completed. Moving Average Reward over last 100 episodes: -141.2844760385496
# Episode 200 completed. Moving Average Reward over last 100 episodes: -130.47072264862973
# Episode 250 completed. Moving Average Reward over last 100 episodes: -114.79339542908778
# Episode 300 completed. Moving Average Reward over last 100 episodes: -114.0773899436888
# Episode 350 completed. Moving Average Reward over last 100 episodes: -130.4011465326468
# Episode 400 completed. Moving Average Reward over last 100 episodes: -116.58752759703324
# Episode 450 completed. Moving Average Reward over last 100 episodes: -93.90547993201852
# Episode 500 completed. Moving Average Reward over last 100 episodes: -85.65795288410455
# Episode 550 completed. Moving Average Reward over last 100 episodes: -90.74154671897118
# Episode 600 completed. Moving Average Reward over last 100 episodes: -108.84967557581506
# Episode 650 completed. Moving Average Reward over last 100 episodes: -100.00363841340437
# Episode 700 completed. Moving Average Reward over last 100 episodes: -96.90183845227806
# Episode 750 completed. Moving Average Reward over last 100 episodes: -134.19581750503522
# Episode 800 completed. Moving Average Reward over last 100 episodes: -121.09689166065418
# Episode 850 completed. Moving Average Reward over last 100 episodes: -76.8314347539308
# Episode 900 completed. Moving Average Reward over last 100 episodes: -84.22333461468197
# Episode 950 completed. Moving Average Reward over last 100 episodes: -90.96888084915723
# Episode 1000 completed. Moving Average Reward over last 100 episodes: -71.30263179945246

# %%
n_test_episodes = 100
total_rewards = 0.0

for episode in range(n_test_episodes):
    state, _ = env.reset()
    state = discretize_state(state)
    done = False
    episode_reward = 0.0
    
    while not done:
        action = np.argmax(Q[state])  # action with the highest Q-value
        next_state, reward, terminated, truncated, _ = env.step(action)
        next_state = discretize_state(next_state)
        
        episode_reward += reward
        state = next_state
        done = terminated or truncated
    
    total_rewards += episode_reward

average_reward = total_rewards / n_test_episodes
print(f"Average reward over {n_test_episodes} test episodes: {average_reward}")
# Out:
# Average reward over 100 test episodes: -101.77052318594659

# %% [markdown]
# ## (f) (10 points)
# Again, train a policy and evaluate it. Plot a curve showing the progress of training,
# i.e., the quality of the policy over the number of game steps (frames) trained on. Interpret the
# learning curve. What can be said about the performance of the algorithm with these parameters
# and this state representation on the given task? How does this compare to the performance of
# Monte-Carlo?

# %%
env = gym.make("LunarLander-v2")

n_episodes = 5000
timesteps=1000
epsilon = 0.1
alpha = 0.1
gamma = 0.99
step_size = 50  
moving_average_window = 100  

Q = defaultdict(lambda: np.zeros(env.action_space.n))

def choose_action(state):
    if np.random.rand() < epsilon:
        return np.random.choice(env.action_space.n)
    else:
        return np.argmax(Q[state])

episode_numbers = []
moving_average_rewards = []

last_n_rewards = []  # To keep the rewards of the last MA episodes

for episode in range(1, n_episodes + 1):
    episode_rewards = 0
    state, _ = env.reset()
    state = discretize_state(state)
    
    done = False
    episode_states_actions = []
    episode_rewards = []
    
    for _ in range(timesteps):
        action = choose_action(state)
        next_state, reward, terminated, truncated, _ = env.step(action)
        next_state = discretize_state(next_state)
        
        # Update Q-table for Q(s,a)
        Q[state][action] = Q[state][action]  + alpha * (reward + gamma * np.argmax(Q[next_state]) - Q[state][action])

        episode_states_actions.append((state, action))
        episode_rewards.append(reward)
        
        state = next_state
        done = terminated or truncated

        if done:
            break

    total_episode_reward = sum(episode_rewards)
    last_n_rewards.append(total_episode_reward)
    
    if len(last_n_rewards) > moving_average_window:
        last_n_rewards.pop(0)
    
    moving_average = np.mean(last_n_rewards)
    
    if episode % step_size == 0:
        episode_numbers.append(episode)
        moving_average_rewards.append(moving_average)
        print(f"Episode {episode} completed. Moving Average Reward over last {moving_average_window} episodes: {moving_average}")
# Out:
# Episode 50 completed. Moving Average Reward over last 100 episodes: -150.98529280479494
# Episode 100 completed. Moving Average Reward over last 100 episodes: -133.5234933239676
# Episode 150 completed. Moving Average Reward over last 100 episodes: -119.73799858563899
# Episode 200 completed. Moving Average Reward over last 100 episodes: -113.34765308546405
# Episode 250 completed. Moving Average Reward over last 100 episodes: -117.84195057210782
# Episode 300 completed. Moving Average Reward over last 100 episodes: -151.65784389339984
# Episode 350 completed. Moving Average Reward over last 100 episodes: -150.9022162968535
# Episode 400 completed. Moving Average Reward over last 100 episodes: -136.8252153011267
# Episode 450 completed. Moving Average Reward over last 100 episodes: -127.65401507402724
# Episode 500 completed. Moving Average Reward over last 100 episodes: -103.48721800943473
# Episode 550 completed. Moving Average Reward over last 100 episodes: -99.93859966078418
# Episode 600 completed. Moving Average Reward over last 100 episodes: -113.12111825323903
# Episode 650 completed. Moving Average Reward over last 100 episodes: -118.54215898019292
# Episode 700 completed. Moving Average Reward over last 100 episodes: -103.75277206526881
# Episode 750 completed. Moving Average Reward over last 100 episodes: -102.33895491032742
# Episode 800 completed. Moving Average Reward over last 100 episodes: -110.31895116583512
# Episode 850 completed. Moving Average Reward over last 100 episodes: -111.91058665845107
# Episode 900 completed. Moving Average Reward over last 100 episodes: -112.78299753716885
# Episode 950 completed. Moving Average Reward over last 100 episodes: -111.63850989202072
# Episode 1000 completed. Moving Average Reward over last 100 episodes: -92.40804971522695
# Episode 1050 completed. Moving Average Reward over last 100 episodes: -83.63909189991888
# Episode 1100 completed. Moving Average Reward over last 100 episodes: -86.6222323917991
# Episode 1150 completed. Moving Average Reward over last 100 episodes: -98.5819687148963
# Episode 1200 completed. Moving Average Reward over last 100 episodes: -116.60765586845841
# Episode 1250 completed. Moving Average Reward over last 100 episodes: -106.74749873778902
# Episode 1300 completed. Moving Average Reward over last 100 episodes: -113.08095816595453
# Episode 1350 completed. Moving Average Reward over last 100 episodes: -115.33308216682325
# Episode 1400 completed. Moving Average Reward over last 100 episodes: -102.45750453215493
# Episode 1450 completed. Moving Average Reward over last 100 episodes: -89.6223865706735
# Episode 1500 completed. Moving Average Reward over last 100 episodes: -73.53697721608827
# Episode 1550 completed. Moving Average Reward over last 100 episodes: -85.60741353956894
# Episode 1600 completed. Moving Average Reward over last 100 episodes: -95.0083055579314
# Episode 1650 completed. Moving Average Reward over last 100 episodes: -89.3712058437359
# Episode 1700 completed. Moving Average Reward over last 100 episodes: -87.91108205532944
# Episode 1750 completed. Moving Average Reward over last 100 episodes: -93.39873992989698
# Episode 1800 completed. Moving Average Reward over last 100 episodes: -95.25209214615262
# Episode 1850 completed. Moving Average Reward over last 100 episodes: -89.64237600293842
# Episode 1900 completed. Moving Average Reward over last 100 episodes: -103.2907010835564
# Episode 1950 completed. Moving Average Reward over last 100 episodes: -114.91258595923884
# Episode 2000 completed. Moving Average Reward over last 100 episodes: -100.1307268856964
# Episode 2050 completed. Moving Average Reward over last 100 episodes: -95.34415449299065
# Episode 2100 completed. Moving Average Reward over last 100 episodes: -90.76041165540886
# Episode 2150 completed. Moving Average Reward over last 100 episodes: -91.04010699780532
# Episode 2200 completed. Moving Average Reward over last 100 episodes: -81.74934151762372
# Episode 2250 completed. Moving Average Reward over last 100 episodes: -82.38905078239948
# Episode 2300 completed. Moving Average Reward over last 100 episodes: -100.65462762439887
# Episode 2350 completed. Moving Average Reward over last 100 episodes: -100.50977360030305
# Episode 2400 completed. Moving Average Reward over last 100 episodes: -98.35612133760304
# Episode 2450 completed. Moving Average Reward over last 100 episodes: -80.46406351330485
# Episode 2500 completed. Moving Average Reward over last 100 episodes: -81.32442323621345
# Episode 2550 completed. Moving Average Reward over last 100 episodes: -85.45739589681067
# Episode 2600 completed. Moving Average Reward over last 100 episodes: -99.13771683865703
# Episode 2650 completed. Moving Average Reward over last 100 episodes: -102.11657454296964
# Episode 2700 completed. Moving Average Reward over last 100 episodes: -93.33622942998895
# Episode 2750 completed. Moving Average Reward over last 100 episodes: -110.74084297542177
# Episode 2800 completed. Moving Average Reward over last 100 episodes: -121.90458574015958
# Episode 2850 completed. Moving Average Reward over last 100 episodes: -90.2644600527241
# Episode 2900 completed. Moving Average Reward over last 100 episodes: -74.1781675701098
# Episode 2950 completed. Moving Average Reward over last 100 episodes: -79.52673256249875
# Episode 3000 completed. Moving Average Reward over last 100 episodes: -89.7394090581217
# Episode 3050 completed. Moving Average Reward over last 100 episodes: -133.90957176545692
# Episode 3100 completed. Moving Average Reward over last 100 episodes: -113.97885806312165
# Episode 3150 completed. Moving Average Reward over last 100 episodes: -93.78134695242274
# Episode 3200 completed. Moving Average Reward over last 100 episodes: -106.54260736051442
# Episode 3250 completed. Moving Average Reward over last 100 episodes: -92.20356574776628
# Episode 3300 completed. Moving Average Reward over last 100 episodes: -69.05815225127611
# Episode 3350 completed. Moving Average Reward over last 100 episodes: -86.54457285226681
# Episode 3400 completed. Moving Average Reward over last 100 episodes: -113.05473185076083
# Episode 3450 completed. Moving Average Reward over last 100 episodes: -93.46277866112315
# Episode 3500 completed. Moving Average Reward over last 100 episodes: -98.20102250891503
# Episode 3550 completed. Moving Average Reward over last 100 episodes: -94.11160081274932
# Episode 3600 completed. Moving Average Reward over last 100 episodes: -101.49267602121407
# Episode 3650 completed. Moving Average Reward over last 100 episodes: -107.35019182534394
# Episode 3700 completed. Moving Average Reward over last 100 episodes: -92.0181867535144
# Episode 3750 completed. Moving Average Reward over last 100 episodes: -93.59901891440444
# Episode 3800 completed. Moving Average Reward over last 100 episodes: -87.46847061125152
# Episode 3850 completed. Moving Average Reward over last 100 episodes: -89.7479624201608
# Episode 3900 completed. Moving Average Reward over last 100 episodes: -102.16381317190731
# Episode 3950 completed. Moving Average Reward over last 100 episodes: -94.04577879226984
# Episode 4000 completed. Moving Average Reward over last 100 episodes: -95.24238125965837
# Episode 4050 completed. Moving Average Reward over last 100 episodes: -104.51652932339742
# Episode 4100 completed. Moving Average Reward over last 100 episodes: -93.08361801190784
# Episode 4150 completed. Moving Average Reward over last 100 episodes: -106.39371052501063
# Episode 4200 completed. Moving Average Reward over last 100 episodes: -112.66994108029625
# Episode 4250 completed. Moving Average Reward over last 100 episodes: -102.67682796153173
# Episode 4300 completed. Moving Average Reward over last 100 episodes: -83.66250654386384
# Episode 4350 completed. Moving Average Reward over last 100 episodes: -68.40359252505158
# Episode 4400 completed. Moving Average Reward over last 100 episodes: -68.69250296435038
# Episode 4450 completed. Moving Average Reward over last 100 episodes: -64.02000638237931
# Episode 4500 completed. Moving Average Reward over last 100 episodes: -90.60080378013566
# Episode 4550 completed. Moving Average Reward over last 100 episodes: -91.21756909158161
# Episode 4600 completed. Moving Average Reward over last 100 episodes: -68.4329579642562
# Episode 4650 completed. Moving Average Reward over last 100 episodes: -66.05482332999227
# Episode 4700 completed. Moving Average Reward over last 100 episodes: -73.85174022989037
# Episode 4750 completed. Moving Average Reward over last 100 episodes: -92.28764353196297
# Episode 4800 completed. Moving Average Reward over last 100 episodes: -93.04225608543615
# Episode 4850 completed. Moving Average Reward over last 100 episodes: -95.6348716243518
# Episode 4900 completed. Moving Average Reward over last 100 episodes: -116.4478173337426
# Episode 4950 completed. Moving Average Reward over last 100 episodes: -120.72577134374849
# Episode 5000 completed. Moving Average Reward over last 100 episodes: -107.10614083021949

# %%
plt.figure(figsize=(10, 6))
plt.plot(episode_numbers, moving_average_rewards, label='Q Agent', marker='o')
plt.axhline(y=random_avg_reward, color='r', linestyle='--', label='Random Agent')
plt.xlabel('Episodes')
plt.ylabel('Average Reward')
plt.title('Performance Comparison: Q-learning Agent vs Random Agent')
plt.legend()
plt.grid(True)
plt.show()

# %%
n_test_episodes = 100
total_rewards = 0.0

for episode in range(n_test_episodes):
    state, _ = env.reset()
    state = discretize_state(state)
    done = False
    episode_reward = 0.0
    
    while not done:
        action = np.argmax(Q[state])  # action with the highest Q-value
        next_state, reward, terminated, truncated, _ = env.step(action)
        next_state = discretize_state(next_state)
        
        episode_reward += reward
        state = next_state
        done = terminated or truncated
    
    total_rewards += episode_reward

average_reward = total_rewards / n_test_episodes
print(f"Average reward over {n_test_episodes} test episodes: {average_reward}")
# Out:
# Average reward over 100 test episodes: -114.33418782505287

# %% [markdown]
# ## (g) (20 points)
# Pick one of the algorithms and try to tune the parameters as well as the discretization in order to improve the performance. Interpret the results of the experiments. Do the
# optimal parameter values depend on each other?
#
# Hint: The paper https://arxiv.org/abs/2011.11850 might give some useful information
# about reasonable parameter values.
#
# Having a decay exploration factor seem to help the agent alot, allowing it explore freely while learning and then reducing it down to be able to greedily exploited the seen paths once it has explored enough.
#
# The Q-learning agent seems to learn better with a slightly higher learning rate but if it is too high then it will struggle because of the initial high exploration rate.
#
# Setting good bounds for the discretized state variables seems to help as well.

# %%
import math
def decay_function(episode):
    min_epsilon = 0.01
    max_epsilon = 1.0
    return max(min_epsilon, min(max_epsilon, 1.0 - math.log10((episode + 1) / (n_episodes * 0.1))))

def evaluate_greedy_policy(env, Q, n_episodes=100):
    total_rewards = 0
    for _ in range(n_episodes):
        state, _ = env.reset()
        state = discretize_state(state)
        done = False
        episode_rewards = 0
        
        while not done:
            action = np.argmax(Q[state])
            
            next_state, reward, terminated, truncated, _ = env.step(action)
            next_state = discretize_state(next_state)
            
            episode_rewards += reward
            state = next_state
            done = terminated or truncated
            
        total_rewards += episode_rewards
        
    average_reward = total_rewards / n_episodes
    return average_reward

# %%
env = gym.make("LunarLander-v2")

n_episodes = 10000
timesteps=1000
epsilon = 0.1
alpha = 0.2
gamma = 0.99
step_size = 50  
moving_average_window = 100  

curr_epsilon = 1.0

def decay_function(episode):
    min_epsilon = 0.01
    max_epsilon = 1.0
    return max(min_epsilon, min(max_epsilon, 1.0 - math.log10((episode + 1) / (n_episodes * 0.1))))


Q = defaultdict(lambda: np.zeros(env.action_space.n))

def choose_action(state, epsilon):
    if np.random.rand() < epsilon:
        return np.random.choice(env.action_space.n)
    else:
        return np.argmax(Q[state])

episode_numbers = []
moving_average_rewards = []

last_n_rewards = []  # To keep the rewards of the last MA episodes

for episode in range(1, n_episodes + 1):
    curr_epsilon = decay_function(episode)
    episode_rewards = 0
    state, _ = env.reset()
    state = discretize_state(state)
    
    done = False
    episode_states_actions = []
    episode_rewards = []
    
    for _ in range(timesteps):
        action = choose_action(state, curr_epsilon)
        next_state, reward, terminated, truncated, _ = env.step(action)
        next_state = discretize_state(next_state)
        
        # Update Q-table for Q(s,a)
        Q[state][action] = Q[state][action]  + alpha * (reward + gamma * np.argmax(Q[next_state]) - Q[state][action])

        episode_states_actions.append((state, action))
        episode_rewards.append(reward)
        
        state = next_state
        done = terminated or truncated

        if done:
            break

    total_episode_reward = sum(episode_rewards)
    last_n_rewards.append(total_episode_reward)
    
    if len(last_n_rewards) > moving_average_window:
        last_n_rewards.pop(0)
    
    moving_average = np.mean(last_n_rewards)
    
    if episode % step_size == 0:
        episode_numbers.append(episode)
        moving_average_rewards.append(moving_average)
        print(f"Episode {episode} completed. Moving Average Reward over last {moving_average_window} episodes: {moving_average}")
# Out:
# Episode 50 completed. Moving Average Reward over last 100 episodes: -184.875364606882
# Episode 100 completed. Moving Average Reward over last 100 episodes: -198.40493056372975
# Episode 150 completed. Moving Average Reward over last 100 episodes: -198.84018322748904
# Episode 200 completed. Moving Average Reward over last 100 episodes: -181.7207283295954
# Episode 250 completed. Moving Average Reward over last 100 episodes: -184.22322065435282
# Episode 300 completed. Moving Average Reward over last 100 episodes: -185.32629068573303
# Episode 350 completed. Moving Average Reward over last 100 episodes: -194.76590400322476
# Episode 400 completed. Moving Average Reward over last 100 episodes: -184.35258026429292
# Episode 450 completed. Moving Average Reward over last 100 episodes: -177.05383472244858
# Episode 500 completed. Moving Average Reward over last 100 episodes: -183.74166172008566
# Episode 550 completed. Moving Average Reward over last 100 episodes: -184.02904843531113
# Episode 600 completed. Moving Average Reward over last 100 episodes: -195.33598675178885
# Episode 650 completed. Moving Average Reward over last 100 episodes: -189.05852211679976
# Episode 700 completed. Moving Average Reward over last 100 episodes: -182.97299094442994
# Episode 750 completed. Moving Average Reward over last 100 episodes: -178.04860425278963
# Episode 800 completed. Moving Average Reward over last 100 episodes: -167.17786369084016
# Episode 850 completed. Moving Average Reward over last 100 episodes: -180.99990392696455
# Episode 900 completed. Moving Average Reward over last 100 episodes: -186.85071668268063
# Episode 950 completed. Moving Average Reward over last 100 episodes: -192.06786092879466
# Episode 1000 completed. Moving Average Reward over last 100 episodes: -200.9549453280302
# Episode 1050 completed. Moving Average Reward over last 100 episodes: -193.6847439145202
# Episode 1100 completed. Moving Average Reward over last 100 episodes: -190.19757885907208
# Episode 1150 completed. Moving Average Reward over last 100 episodes: -186.26683047281574
# Episode 1200 completed. Moving Average Reward over last 100 episodes: -164.12559344962716
# Episode 1250 completed. Moving Average Reward over last 100 episodes: -147.37864743452664
# Episode 1300 completed. Moving Average Reward over last 100 episodes: -152.62741664249108
# Episode 1350 completed. Moving Average Reward over last 100 episodes: -147.63167982121945
# Episode 1400 completed. Moving Average Reward over last 100 episodes: -144.78786195023773
# Episode 1450 completed. Moving Average Reward over last 100 episodes: -153.3492000554433
# Episode 1500 completed. Moving Average Reward over last 100 episodes: -151.3458568482201
# Episode 1550 completed. Moving Average Reward over last 100 episodes: -138.60658390407664
# Episode 1600 completed. Moving Average Reward over last 100 episodes: -156.6219600865877
# Episode 1650 completed. Moving Average Reward over last 100 episodes: -155.66496993684322
# Episode 1700 completed. Moving Average Reward over last 100 episodes: -120.47495323016214
# Episode 1750 completed. Moving Average Reward over last 100 episodes: -130.9102698901031
# Episode 1800 completed. Moving Average Reward over last 100 episodes: -144.18155651873806
# Episode 1850 completed. Moving Average Reward over last 100 episodes: -134.39068825232494
# Episode 1900 completed. Moving Average Reward over last 100 episodes: -143.40203850410924
# Episode 1950 completed. Moving Average Reward over last 100 episodes: -144.36207656868606
# Episode 2000 completed. Moving Average Reward over last 100 episodes: -137.60347206972864
# Episode 2050 completed. Moving Average Reward over last 100 episodes: -131.01530414438136
# Episode 2100 completed. Moving Average Reward over last 100 episodes: -119.20046641097034
# Episode 2150 completed. Moving Average Reward over last 100 episodes: -118.43261188309901
# Episode 2200 completed. Moving Average Reward over last 100 episodes: -113.40589276669739
# Episode 2250 completed. Moving Average Reward over last 100 episodes: -106.59012251692118
# Episode 2300 completed. Moving Average Reward over last 100 episodes: -106.47113973941667
# Episode 2350 completed. Moving Average Reward over last 100 episodes: -106.118034898741
# Episode 2400 completed. Moving Average Reward over last 100 episodes: -107.57547811844832
# Episode 2450 completed. Moving Average Reward over last 100 episodes: -102.08756488677167
# Episode 2500 completed. Moving Average Reward over last 100 episodes: -103.12409382731161
# Episode 2550 completed. Moving Average Reward over last 100 episodes: -118.07301504039415
# Episode 2600 completed. Moving Average Reward over last 100 episodes: -122.78102230703554
# Episode 2650 completed. Moving Average Reward over last 100 episodes: -108.25530716343759
# Episode 2700 completed. Moving Average Reward over last 100 episodes: -104.52934461935932
# Episode 2750 completed. Moving Average Reward over last 100 episodes: -113.79682154329629
# Episode 2800 completed. Moving Average Reward over last 100 episodes: -101.03905922665939
# Episode 2850 completed. Moving Average Reward over last 100 episodes: -92.9527115291395
# Episode 2900 completed. Moving Average Reward over last 100 episodes: -101.5137583887439
# Episode 2950 completed. Moving Average Reward over last 100 episodes: -107.42907580010672
# Episode 3000 completed. Moving Average Reward over last 100 episodes: -110.74673072119798
# Episode 3050 completed. Moving Average Reward over last 100 episodes: -105.47950160505172
# Episode 3100 completed. Moving Average Reward over last 100 episodes: -108.85683295598115
# Episode 3150 completed. Moving Average Reward over last 100 episodes: -106.30233969950922
# Episode 3200 completed. Moving Average Reward over last 100 episodes: -97.6165626745646
# Episode 3250 completed. Moving Average Reward over last 100 episodes: -101.20523612375527
# Episode 3300 completed. Moving Average Reward over last 100 episodes: -92.14925593629259
# Episode 3350 completed. Moving Average Reward over last 100 episodes: -79.35281874158996
# Episode 3400 completed. Moving Average Reward over last 100 episodes: -79.81688965368701
# Episode 3450 completed. Moving Average Reward over last 100 episodes: -81.46328996304037
# Episode 3500 completed. Moving Average Reward over last 100 episodes: -80.94016268130994
# Episode 3550 completed. Moving Average Reward over last 100 episodes: -94.07011049423751
# Episode 3600 completed. Moving Average Reward over last 100 episodes: -95.93013566811271
# Episode 3650 completed. Moving Average Reward over last 100 episodes: -84.24153360718361
# Episode 3700 completed. Moving Average Reward over last 100 episodes: -88.14362905242197
# Episode 3750 completed. Moving Average Reward over last 100 episodes: -97.74371619514051
# Episode 3800 completed. Moving Average Reward over last 100 episodes: -96.95083555495974
# Episode 3850 completed. Moving Average Reward over last 100 episodes: -84.51937797601511
# Episode 3900 completed. Moving Average Reward over last 100 episodes: -86.16787230281282
# Episode 3950 completed. Moving Average Reward over last 100 episodes: -95.43738220510387
# Episode 4000 completed. Moving Average Reward over last 100 episodes: -104.02972245941152
# Episode 4050 completed. Moving Average Reward over last 100 episodes: -96.75971200473914
# Episode 4100 completed. Moving Average Reward over last 100 episodes: -83.50579034400334
# Episode 4150 completed. Moving Average Reward over last 100 episodes: -94.70780138744236
# Episode 4200 completed. Moving Average Reward over last 100 episodes: -98.75029384354684
# Episode 4250 completed. Moving Average Reward over last 100 episodes: -101.726648077659
# Episode 4300 completed. Moving Average Reward over last 100 episodes: -104.19016392061006
# Episode 4350 completed. Moving Average Reward over last 100 episodes: -96.81873668917295
# Episode 4400 completed. Moving Average Reward over last 100 episodes: -95.09150942810578
# Episode 4450 completed. Moving Average Reward over last 100 episodes: -102.70243847977517
# Episode 4500 completed. Moving Average Reward over last 100 episodes: -98.28526175128505
# Episode 4550 completed. Moving Average Reward over last 100 episodes: -95.84773846733536
# Episode 4600 completed. Moving Average Reward over last 100 episodes: -102.04814404054304
# Episode 4650 completed. Moving Average Reward over last 100 episodes: -105.62926558056296
# Episode 4700 completed. Moving Average Reward over last 100 episodes: -103.95764435867036
# Episode 4750 completed. Moving Average Reward over last 100 episodes: -90.50239281652402
# Episode 4800 completed. Moving Average Reward over last 100 episodes: -87.31312403582123
# Episode 4850 completed. Moving Average Reward over last 100 episodes: -101.70274459425406
# Episode 4900 completed. Moving Average Reward over last 100 episodes: -89.48749925640844
# Episode 4950 completed. Moving Average Reward over last 100 episodes: -77.29376013764069
# Episode 5000 completed. Moving Average Reward over last 100 episodes: -97.12606079516847
# Episode 5050 completed. Moving Average Reward over last 100 episodes: -83.61003794229971
# Episode 5100 completed. Moving Average Reward over last 100 episodes: -77.37040024091316
# Episode 5150 completed. Moving Average Reward over last 100 episodes: -89.96164915816071
# Episode 5200 completed. Moving Average Reward over last 100 episodes: -78.92667022503191
# Episode 5250 completed. Moving Average Reward over last 100 episodes: -77.87937044972358
# Episode 5300 completed. Moving Average Reward over last 100 episodes: -100.58727699708997
# Episode 5350 completed. Moving Average Reward over last 100 episodes: -107.25420961122322
# Episode 5400 completed. Moving Average Reward over last 100 episodes: -103.69105973319581
# Episode 5450 completed. Moving Average Reward over last 100 episodes: -107.97651675666727
# Episode 5500 completed. Moving Average Reward over last 100 episodes: -103.40828613580305
# Episode 5550 completed. Moving Average Reward over last 100 episodes: -98.21517345099352
# Episode 5600 completed. Moving Average Reward over last 100 episodes: -106.68560348040208
# Episode 5650 completed. Moving Average Reward over last 100 episodes: -115.74922528757308
# Episode 5700 completed. Moving Average Reward over last 100 episodes: -101.32645484134508
# Episode 5750 completed. Moving Average Reward over last 100 episodes: -85.15161476422176
# Episode 5800 completed. Moving Average Reward over last 100 episodes: -95.62885374696609
# Episode 5850 completed. Moving Average Reward over last 100 episodes: -90.72660309145672
# Episode 5900 completed. Moving Average Reward over last 100 episodes: -87.62732713448844
# Episode 5950 completed. Moving Average Reward over last 100 episodes: -91.2176379282848
# Episode 6000 completed. Moving Average Reward over last 100 episodes: -74.33657944250639
# Episode 6050 completed. Moving Average Reward over last 100 episodes: -84.20152011462125
# Episode 6100 completed. Moving Average Reward over last 100 episodes: -85.79499626685354
# Episode 6150 completed. Moving Average Reward over last 100 episodes: -81.37223607485483
# Episode 6200 completed. Moving Average Reward over last 100 episodes: -92.99822725938814
# Episode 6250 completed. Moving Average Reward over last 100 episodes: -94.90697493974164
# Episode 6300 completed. Moving Average Reward over last 100 episodes: -100.90410799271767
# Episode 6350 completed. Moving Average Reward over last 100 episodes: -86.67558819157495
# Episode 6400 completed. Moving Average Reward over last 100 episodes: -101.10769110524707
# Episode 6450 completed. Moving Average Reward over last 100 episodes: -122.16954337184576
# Episode 6500 completed. Moving Average Reward over last 100 episodes: -121.17147089065845
# Episode 6550 completed. Moving Average Reward over last 100 episodes: -112.16349350286501
# Episode 6600 completed. Moving Average Reward over last 100 episodes: -100.78844148883121
# Episode 6650 completed. Moving Average Reward over last 100 episodes: -102.49706128145115
# Episode 6700 completed. Moving Average Reward over last 100 episodes: -101.6227019060837
# Episode 6750 completed. Moving Average Reward over last 100 episodes: -117.43437282299006
# Episode 6800 completed. Moving Average Reward over last 100 episodes: -113.07674190772202
# Episode 6850 completed. Moving Average Reward over last 100 episodes: -87.32546371256323
# Episode 6900 completed. Moving Average Reward over last 100 episodes: -87.67962407025666
# Episode 6950 completed. Moving Average Reward over last 100 episodes: -95.47406510437544
# Episode 7000 completed. Moving Average Reward over last 100 episodes: -89.9542109545294
# Episode 7050 completed. Moving Average Reward over last 100 episodes: -97.350037751414
# Episode 7100 completed. Moving Average Reward over last 100 episodes: -95.56011717335402
# Episode 7150 completed. Moving Average Reward over last 100 episodes: -99.45779366008023
# Episode 7200 completed. Moving Average Reward over last 100 episodes: -95.98772996604423
# Episode 7250 completed. Moving Average Reward over last 100 episodes: -87.07362006251533
# Episode 7300 completed. Moving Average Reward over last 100 episodes: -98.44581654637484
# Episode 7350 completed. Moving Average Reward over last 100 episodes: -86.45126558680899
# Episode 7400 completed. Moving Average Reward over last 100 episodes: -59.39441965183515
# Episode 7450 completed. Moving Average Reward over last 100 episodes: -55.71454419186426
# Episode 7500 completed. Moving Average Reward over last 100 episodes: -72.22729476880231
# Episode 7550 completed. Moving Average Reward over last 100 episodes: -80.26487829462529
# Episode 7600 completed. Moving Average Reward over last 100 episodes: -71.73242628732433
# Episode 7650 completed. Moving Average Reward over last 100 episodes: -57.383239401804964
# Episode 7700 completed. Moving Average Reward over last 100 episodes: -68.54776575778118
# Episode 7750 completed. Moving Average Reward over last 100 episodes: -96.90344200890934
# Episode 7800 completed. Moving Average Reward over last 100 episodes: -90.45256255182635
# Episode 7850 completed. Moving Average Reward over last 100 episodes: -76.08083303197728
# Episode 7900 completed. Moving Average Reward over last 100 episodes: -81.23059062197069
# Episode 7950 completed. Moving Average Reward over last 100 episodes: -82.67970599272867
# Episode 8000 completed. Moving Average Reward over last 100 episodes: -75.80075264928931
# Episode 8050 completed. Moving Average Reward over last 100 episodes: -83.59247235580395
# Episode 8100 completed. Moving Average Reward over last 100 episodes: -87.20158612321984
# Episode 8150 completed. Moving Average Reward over last 100 episodes: -74.29046928944693
# Episode 8200 completed. Moving Average Reward over last 100 episodes: -59.20835150561054
# Episode 8250 completed. Moving Average Reward over last 100 episodes: -71.12837645228873
# Episode 8300 completed. Moving Average Reward over last 100 episodes: -78.36115858436892
# Episode 8350 completed. Moving Average Reward over last 100 episodes: -63.91404809258532
# Episode 8400 completed. Moving Average Reward over last 100 episodes: -75.52825610921246
# Episode 8450 completed. Moving Average Reward over last 100 episodes: -79.07768518837307
# Episode 8500 completed. Moving Average Reward over last 100 episodes: -81.3176003309299
# Episode 8550 completed. Moving Average Reward over last 100 episodes: -75.23924269134103
# Episode 8600 completed. Moving Average Reward over last 100 episodes: -61.06463517794689
# Episode 8650 completed. Moving Average Reward over last 100 episodes: -52.62671019251054
# Episode 8700 completed. Moving Average Reward over last 100 episodes: -67.84344589665933
# Episode 8750 completed. Moving Average Reward over last 100 episodes: -79.56988248470353
# Episode 8800 completed. Moving Average Reward over last 100 episodes: -65.09260077804898
# Episode 8850 completed. Moving Average Reward over last 100 episodes: -60.636009895415945
# Episode 8900 completed. Moving Average Reward over last 100 episodes: -58.195496266927734
# Episode 8950 completed. Moving Average Reward over last 100 episodes: -64.98100358115711
# Episode 9000 completed. Moving Average Reward over last 100 episodes: -79.52884078989369
# Episode 9050 completed. Moving Average Reward over last 100 episodes: -63.99584627254081
# Episode 9100 completed. Moving Average Reward over last 100 episodes: -54.464916240626735
# Episode 9150 completed. Moving Average Reward over last 100 episodes: -65.5622467625016
# Episode 9200 completed. Moving Average Reward over last 100 episodes: -75.03922827908227
# Episode 9250 completed. Moving Average Reward over last 100 episodes: -52.44455047770013
# Episode 9300 completed. Moving Average Reward over last 100 episodes: -34.11012834430464
# Episode 9350 completed. Moving Average Reward over last 100 episodes: -40.71543529134248
# Episode 9400 completed. Moving Average Reward over last 100 episodes: -43.314811467527804
# Episode 9450 completed. Moving Average Reward over last 100 episodes: -36.757835150656426
# Episode 9500 completed. Moving Average Reward over last 100 episodes: -28.984263455104134
# Episode 9550 completed. Moving Average Reward over last 100 episodes: -31.246130485736394
# Episode 9600 completed. Moving Average Reward over last 100 episodes: -41.749807344968595
# Episode 9650 completed. Moving Average Reward over last 100 episodes: -54.39867233341179
# Episode 9700 completed. Moving Average Reward over last 100 episodes: -36.52875702243438
# Episode 9750 completed. Moving Average Reward over last 100 episodes: -22.146252401907944
# Episode 9800 completed. Moving Average Reward over last 100 episodes: -34.243327974324856
# Episode 9850 completed. Moving Average Reward over last 100 episodes: -42.80514571225386
# Episode 9900 completed. Moving Average Reward over last 100 episodes: -25.765587292595004
# Episode 9950 completed. Moving Average Reward over last 100 episodes: -8.41726284657998
# Episode 10000 completed. Moving Average Reward over last 100 episodes: -19.68979683225772

# %%
plt.figure(figsize=(10, 6))
plt.plot(episode_numbers, moving_average_rewards, label='Q Agent', marker='o')
plt.axhline(y=random_avg_reward, color='r', linestyle='--', label='Random Agent')
plt.xlabel('Episodes')
plt.ylabel('Average Reward')
plt.title('Performance Comparison: Q-learning Agent vs Random Agent')
plt.legend()
plt.grid(True)
plt.show()

# %%
n_test_episodes = 100
total_rewards = 0.0

for episode in range(n_test_episodes):
    state, _ = env.reset()
    state = discretize_state(state)
    done = False
    episode_reward = 0.0
    
    while not done:
        action = np.argmax(Q[state])  # action with the highest Q-value
        next_state, reward, terminated, truncated, _ = env.step(action)
        next_state = discretize_state(next_state)
        
        episode_reward += reward
        state = next_state
        done = terminated or truncated
    
    total_rewards += episode_reward

average_reward = total_rewards / n_test_episodes
print(f"Average reward over {n_test_episodes} test episodes: {average_reward}")
# Out:
# Average reward over 100 test episodes: 4.913194927165639

# %%
env = gym.make("LunarLander-v2")

n_episodes = 10000
alpha = 0.1
gamma = 0.999
step_size = 50  
moving_average_window = 100  

Q = defaultdict(lambda: np.zeros(env.action_space.n))
N = defaultdict(lambda: np.zeros(env.action_space.n))

def choose_action(state, epsilon):
    if np.random.rand() < epsilon:
        return np.random.choice(env.action_space.n)
    else:
        return np.argmax(Q[state])

curr_epsilon = 1.0

def decay_function(episode):
    min_epsilon = 0.01
    max_epsilon = 1.0
    return max(min_epsilon, min(max_epsilon, 1.0 - math.log10((episode + 1) / (n_episodes * 0.1))))

episode_numbers = []
moving_average_rewards = []
greedy_rewards = []
greedy_episodes = []
last_n_rewards = []

for episode in range(1, n_episodes + 1):
    if episode % 500 == 0: 
        avg_reward = evaluate_greedy_policy(env, Q)
        print(f"Episode {episode}, Average reward over 100 episodes with greedy policy: {avg_reward}")
    
        # store greedy result
        greedy_rewards.append(avg_reward)
        greedy_episodes.append(episode)
    curr_epsilon = decay_function(episode)
    
    state, _ = env.reset()
    state = discretize_state(state)
    
    done = False
    episode_states_actions = []
    episode_rewards = []
    
    while not done:
        action = choose_action(state, curr_epsilon)
        next_state, reward, terminated, truncated, _ = env.step(action)
        next_state = discretize_state(next_state)
        
        episode_states_actions.append((state, action))
        episode_rewards.append(reward)
        
        state = next_state

        done = terminated or truncated

    G = 0
    for t in reversed(range(len(episode_states_actions))):
        state, action = episode_states_actions[t]
        reward = episode_rewards[t]
        
        G = gamma * G + reward
        N[state][action] += 1
        
        Q[state][action] += (G - Q[state][action]) / N[state][action]
    
    total_episode_reward = sum(episode_rewards)
    last_n_rewards.append(total_episode_reward)
    
    if len(last_n_rewards) > moving_average_window:
        last_n_rewards.pop(0)
    
    moving_average = np.mean(last_n_rewards)
    
    if episode % (step_size * 4) == 0:
        episode_numbers.append(episode)
        moving_average_rewards.append(moving_average)
        print(f"Episode {episode} completed. Moving Average Reward over last {moving_average_window} episodes: {moving_average}")
# Out:
# Episode 200 completed. Moving Average Reward over last 100 episodes: -173.51257855534573
# Episode 400 completed. Moving Average Reward over last 100 episodes: -176.3670392567896
# Episode 500, Average reward over 100 episodes with greedy policy: -146.27323983089167
# Episode 600 completed. Moving Average Reward over last 100 episodes: -177.34220046169
# Episode 800 completed. Moving Average Reward over last 100 episodes: -179.74030039564502
# Episode 1000, Average reward over 100 episodes with greedy policy: -67.71916634377375
# Episode 1000 completed. Moving Average Reward over last 100 episodes: -167.20228322763433
# Episode 1200 completed. Moving Average Reward over last 100 episodes: -147.8623649711821
# Episode 1400 completed. Moving Average Reward over last 100 episodes: -128.2724724829452
# Episode 1500, Average reward over 100 episodes with greedy policy: -63.243949747006944
# Episode 1600 completed. Moving Average Reward over last 100 episodes: -109.60678749803397
# Episode 1800 completed. Moving Average Reward over last 100 episodes: -110.09964943348015
# Episode 2000, Average reward over 100 episodes with greedy policy: -52.87968342632714
# Episode 2000 completed. Moving Average Reward over last 100 episodes: -92.41481633778977
# Episode 2200 completed. Moving Average Reward over last 100 episodes: -90.792464821564
# Episode 2400 completed. Moving Average Reward over last 100 episodes: -84.40104656696056
# Episode 2500, Average reward over 100 episodes with greedy policy: -55.76844124910567
# Episode 2600 completed. Moving Average Reward over last 100 episodes: -73.95320354112064
# Episode 2800 completed. Moving Average Reward over last 100 episodes: -69.09354455181774
# Episode 3000, Average reward over 100 episodes with greedy policy: -26.266917374759117
# Episode 3000 completed. Moving Average Reward over last 100 episodes: -61.58310245531947
# Episode 3200 completed. Moving Average Reward over last 100 episodes: -58.461440766908225
# Episode 3400 completed. Moving Average Reward over last 100 episodes: -58.364951864055655
# Episode 3500, Average reward over 100 episodes with greedy policy: -13.755082280270983
# Episode 3600 completed. Moving Average Reward over last 100 episodes: -56.06226148881124
# Episode 3800 completed. Moving Average Reward over last 100 episodes: -52.53898531320742
# Episode 4000, Average reward over 100 episodes with greedy policy: 12.71802734112777
# Episode 4000 completed. Moving Average Reward over last 100 episodes: -46.32187948809922
# Episode 4200 completed. Moving Average Reward over last 100 episodes: -47.201040966589325
# Episode 4400 completed. Moving Average Reward over last 100 episodes: -53.84350706131979
# Episode 4500, Average reward over 100 episodes with greedy policy: 3.285155466080422
# Episode 4600 completed. Moving Average Reward over last 100 episodes: -36.37544234633255
# Episode 4800 completed. Moving Average Reward over last 100 episodes: -43.52172514358736
# Episode 5000, Average reward over 100 episodes with greedy policy: 2.45241586901711
# Episode 5000 completed. Moving Average Reward over last 100 episodes: -36.88064679772567
# Episode 5200 completed. Moving Average Reward over last 100 episodes: -30.008817461770263
# Episode 5400 completed. Moving Average Reward over last 100 episodes: -35.51003751804349
# Episode 5500, Average reward over 100 episodes with greedy policy: -5.221700601835336
# Episode 5600 completed. Moving Average Reward over last 100 episodes: -24.70662157319622
# Episode 5800 completed. Moving Average Reward over last 100 episodes: -33.49937205039494
# Episode 6000, Average reward over 100 episodes with greedy policy: 27.100322481574526
# Episode 6000 completed. Moving Average Reward over last 100 episodes: -18.021401759658403
# Episode 6200 completed. Moving Average Reward over last 100 episodes: -19.032280915201444
# Episode 6400 completed. Moving Average Reward over last 100 episodes: -19.495370576599484
# Episode 6500, Average reward over 100 episodes with greedy policy: 11.226885471912468
# Episode 6600 completed. Moving Average Reward over last 100 episodes: -13.7737479893156
# Episode 6800 completed. Moving Average Reward over last 100 episodes: -19.688962123279424
# Episode 7000, Average reward over 100 episodes with greedy policy: 16.685740368611135
# Episode 7000 completed. Moving Average Reward over last 100 episodes: -13.377375493334878
# Episode 7200 completed. Moving Average Reward over last 100 episodes: -22.39335774543846
# Episode 7400 completed. Moving Average Reward over last 100 episodes: -10.054881878210802
# Episode 7500, Average reward over 100 episodes with greedy policy: 37.89366567634637
# Episode 7600 completed. Moving Average Reward over last 100 episodes: -3.8563527573877594
# Episode 7800 completed. Moving Average Reward over last 100 episodes: -4.7212967360906894
# Episode 8000, Average reward over 100 episodes with greedy policy: 17.58037405801398
# Episode 8000 completed. Moving Average Reward over last 100 episodes: -0.8847641181687648
# Episode 8200 completed. Moving Average Reward over last 100 episodes: -0.027591486988498275
# Episode 8400 completed. Moving Average Reward over last 100 episodes: -3.8649421188376505
# Episode 8500, Average reward over 100 episodes with greedy policy: 22.53986874710019
# Episode 8600 completed. Moving Average Reward over last 100 episodes: 14.922998123099491
# Episode 8800 completed. Moving Average Reward over last 100 episodes: 11.44628199678107
# Episode 9000, Average reward over 100 episodes with greedy policy: 34.81190161356497
# Episode 9000 completed. Moving Average Reward over last 100 episodes: 27.32749806791487
# Episode 9200 completed. Moving Average Reward over last 100 episodes: -4.012961231244389
# Episode 9400 completed. Moving Average Reward over last 100 episodes: 12.987208487723423
# Episode 9500, Average reward over 100 episodes with greedy policy: 24.99065927329757
# Episode 9600 completed. Moving Average Reward over last 100 episodes: 23.148275181311856
# Episode 9800 completed. Moving Average Reward over last 100 episodes: 11.505239125407586
# Episode 10000, Average reward over 100 episodes with greedy policy: 26.650042840079724
# Episode 10000 completed. Moving Average Reward over last 100 episodes: 31.00966845743718

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))

plt.plot(episode_numbers, moving_average_rewards, label='MC Agent (Training)', marker='o')
plt.plot(greedy_episodes, greedy_rewards, label='MC Agent (Greedy)', marker='x')
plt.axhline(y=random_avg_reward, color='r', linestyle='--', label='Random Agent')

plt.xlabel('Episodes')
plt.ylabel('Average Reward')
plt.title('Performance Comparison: MC Agent (Training vs Greedy)')
plt.legend()
plt.grid(True)
plt.show()

# %%
n_test_episodes = 100
total_rewards = 0.0

for episode in range(n_test_episodes):
    state, _ = env.reset()
    state = discretize_state(state)
    done = False
    episode_reward = 0.0
    
    while not done:
        action = np.argmax(Q[state])  # action with the highest Q-value
        next_state, reward, terminated, truncated, _ = env.step(action)
        next_state = discretize_state(next_state)
        
        episode_reward += reward
        state = next_state
        done = terminated or truncated
    
    total_rewards += episode_reward

average_reward = total_rewards / n_test_episodes
print(f"Average reward over {n_test_episodes} test episodes: {average_reward}")
# Out:
# Average reward over 100 test episodes: 31.358593282544515

# %% [markdown]
# ## (h) (10 points)
# Once you have learned a good policy, check whether it is robust enough to handle
# small variations in the environment. One way to do this relatively easily is to enable wind
# (enable_wind and wind_power parameters in textttgym.make) and measure the performance
# of the policy with different amounts of wind.

# %%
n_episodes = 10000
gamma = 0.999
step_size = 200  
moving_average_window = 100  

fig, axs = plt.subplots(3, 1, figsize=(18, 10))

for idx, wind_strength in enumerate([5, 10, 15]):
    env = gym.make("LunarLander-v2", enable_wind=True, wind_power=wind_strength)

    Q = defaultdict(lambda: np.zeros(env.action_space.n))
    N = defaultdict(lambda: np.zeros(env.action_space.n))

    episode_numbers = []
    moving_average_rewards = []
    greedy_rewards = []
    greedy_episodes = []
    last_n_rewards = []
    
    for episode in range(1, n_episodes + 1):
        curr_epsilon = max(0.01, min(1, 1.0 - math.log10((episode + 1) / (n_episodes * 0.1))))
        
        state, _ = env.reset()
        state = discretize_state(state)
        
        done = False
        episode_states_actions = []
        episode_rewards = []
        
        while not done:
            action = choose_action(state, curr_epsilon)
            next_state, reward, terminated, truncated, _ = env.step(action)
            next_state = discretize_state(next_state)
            
            episode_states_actions.append((state, action))
            episode_rewards.append(reward)
            
            state = next_state

            done = terminated or truncated

        G = 0
        for t in reversed(range(len(episode_states_actions))):
            state, action = episode_states_actions[t]
            reward = episode_rewards[t]
            
            G = gamma * G + reward
            N[state][action] += 1
            
            Q[state][action] += (G - Q[state][action]) / N[state][action]
        
        total_episode_reward = sum(episode_rewards)
        last_n_rewards.append(total_episode_reward)
        
        if len(last_n_rewards) > moving_average_window:
            last_n_rewards.pop(0)
        
        moving_average = np.mean(last_n_rewards)
        
        if episode % step_size == 0:
            episode_numbers.append(episode)
            moving_average_rewards.append(moving_average)
            
        if episode % 500 == 0:
            avg_reward = evaluate_greedy_policy(env, Q)
            greedy_rewards.append(avg_reward)
            greedy_episodes.append(episode)

    axs[idx].plot(episode_numbers, moving_average_rewards, label='MC Agent (Training)', marker='o')
    axs[idx].plot(greedy_episodes, greedy_rewards, label='MC Agent (Greedy)', marker='x')
    axs[idx].axhline(y=random_avg_reward, color='r', linestyle='--', label='Random Agent')
    axs[idx].set_title(f'Wind Strength: {wind_strength}')
    axs[idx].set_xlabel('')
    axs[idx].set_ylabel('Average Reward')
    axs[idx].legend()
    axs[idx].grid(True)

plt.show()

# %% [markdown]
# ## (i) (50 bonus points)
# Implement Deep-Q-Learning, i.e., use a neural network as function to
# predict Q values for the actions. Compare the performance to the previous best model. Also,
# compare the run-time required for training. Note that training with Deep-Q-Learning might
# take a lot longer than training the other methods.
#
# Hint: The same paper as above might help getting a reasonable setup for the network and the
# training parameters. It is possible to make the network somewhat smaller (e.g., 2 hidden layers
# with 64 units each might do) to make training a bit less expensive.

# %% [markdown]
# Deep-Q_learning was implemented in a seperate notebook: hw3_DQN.ipynb
#
# The results of training:
#
# ![Alt text](image-1.png)
#
# Test Episode Reward: 219.52606632234247
#
# The DQN agent playing Lunar Lander can be seen in DQN_gameplay.avi
